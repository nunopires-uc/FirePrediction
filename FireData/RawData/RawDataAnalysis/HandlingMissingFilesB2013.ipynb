# %%
import pandas as pd
import requests
import ast
import os
# Out:
# /tmp/ipykernel_15615/1817075740.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
import pandas as pd
_year = 2009
dfMissing = pd.read_csv(f'error_rows{_year}.csv')
print(len(dfMissing))
# Out:
# 13

# %%
print(len([f for f in os.listdir(f'MissingFiles{_year}') if os.path.isfile(os.path.join(f'MissingFiles{_year}', f))]))
# Out:
# 0

# %%
_year = 2005
dfMissing = pd.read_csv(f'error_rows{_year}.csv')
print(len(dfMissing))
for r in range(0, len(dfMissing)):
    row = dfMissing.iloc[r]

    LAT = row['LAT']
    _DATA = row['data_alerta']
    LON = row['LON']

    _fileName_radiation = _DATA + f"_{LAT}_{LON}_radiation"
    _fileName = _DATA + f"_{LAT}_{LON}"


    #RawData/RawDataAnalysis/MissingFiles2012
    #url_rad = f"https://archive-api.open-meteo.com/v1/archive?latitude={LAT}&longitude={LON}&start_date={_DATA}&end_date={_DATA}&hourly=shortwave_radiation,direct_radiation,diffuse_radiation,direct_normal_irradiance,global_tilted_irradiance,terrestrial_radiation,shortwave_radiation_instant,direct_radiation_instant,diffuse_radiation_instant,direct_normal_irradiance_instant,global_tilted_irradiance_instant,terrestrial_radiation_instant"
    url = f"https://archive-api.open-meteo.com/v1/archive?latitude={LAT}&longitude={LON}&start_date={_DATA}&end_date={_DATA}&hourly=temperature_2m,relative_humidity_2m,dew_point_2m,apparent_temperature,precipitation,rain,snowfall,snow_depth,weather_code,pressure_msl,surface_pressure,cloud_cover,cloud_cover_low,cloud_cover_mid,cloud_cover_high,et0_fao_evapotranspiration,vapour_pressure_deficit,wind_speed_10m,wind_speed_100m,wind_direction_10m,wind_direction_100m,wind_gusts_10m,soil_temperature_0_to_7cm,soil_temperature_7_to_28cm,soil_temperature_28_to_100cm,soil_temperature_100_to_255cm,soil_moisture_0_to_7cm,soil_moisture_7_to_28cm,soil_moisture_28_to_100cm,soil_moisture_100_to_255cm,is_day,sunshine_duration,shortwave_radiation_instant,direct_radiation_instant,diffuse_radiation_instant,direct_normal_irradiance_instant,global_tilted_irradiance_instant,terrestrial_radiation_instant&timezone=GMT"
    response = requests.get(url)
    #response_rad = requests.get(url_rad)

    print(response.status_code)
    #print(response_rad.status_code)

    if((response.status_code == 200)):
        data = response.json()
        #data_rad = response_rad.json()

        df = pd.json_normalize(data)
        df.to_csv(f"MissingFiles{_year}/{_fileName}.csv", index=False)

        #df_rad = pd.json_normalize(data_rad)
        #df_rad.to_csv(f"MissingFiles{_year}/{_fileName_radiation}.csv", index=False)
    else:
        print("Error row:", str(r))
# Out:
# 17
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200

# %%
current_dir = os.getcwd()
root_dir = os.path.dirname(os.path.dirname(current_dir))
_RAWFIRESPATH = f"{root_dir}/RawData/Historical_FiresRAW"

_year = 2005
_file = f"{_RAWFIRESPATH}/{_year}/2005-01-01_37.7388357_-8.750062888101874.csv"
df = pd.read_csv(f"{_file}")

column_names = df.columns.tolist()

column_names = df.columns.tolist()

columns_to_remove = [col for col in column_names if 'hourly_units' in col]
columns_to_remove.extend(['latitude', 'longitude', 'generationtime_ms', 'utc_offset_seconds', 'timezone', 'timezone_abbreviation'])

df = df.drop(columns=columns_to_remove)

updated_column_names = df.columns.tolist()

_file_radiation = _file.replace(".csv", "_radiation.csv")
df = pd.read_csv(f"{_file_radiation}")

df = pd.read_csv(f"{_file_radiation}")
column_names = df.columns.tolist()
print(column_names)

column_names = df.columns.tolist()

columns_to_remove = [col for col in column_names if 'hourly_units' in col]
columns_to_remove.extend(['latitude', 'longitude', 'generationtime_ms', 'utc_offset_seconds', 'timezone', 'timezone_abbreviation', 'elevation', 'hourly.time', 'hourly.global_tilted_irradiance_instant', 'hourly.diffuse_radiation_instant', 'hourly.terrestrial_radiation_instant', 'hourly.direct_radiation_instant', 'hourly.shortwave_radiation_instant', 'hourly.direct_normal_irradiance_instant'])

df = df.drop(columns=columns_to_remove)

updated_column_names_radiation = df.columns.tolist()
print(updated_column_names_radiation)

set1 = set(updated_column_names_radiation)
set2 = set(updated_column_names)

common_elements = set1 & set2

print(common_elements)
# Out:
# ['latitude', 'longitude', 'generationtime_ms', 'utc_offset_seconds', 'timezone', 'timezone_abbreviation', 'elevation', 'hourly_units.time', 'hourly_units.shortwave_radiation', 'hourly_units.direct_radiation', 'hourly_units.diffuse_radiation', 'hourly_units.direct_normal_irradiance', 'hourly_units.global_tilted_irradiance', 'hourly_units.terrestrial_radiation', 'hourly_units.shortwave_radiation_instant', 'hourly_units.direct_radiation_instant', 'hourly_units.diffuse_radiation_instant', 'hourly_units.direct_normal_irradiance_instant', 'hourly_units.global_tilted_irradiance_instant', 'hourly_units.terrestrial_radiation_instant', 'hourly.time', 'hourly.shortwave_radiation', 'hourly.direct_radiation', 'hourly.diffuse_radiation', 'hourly.direct_normal_irradiance', 'hourly.global_tilted_irradiance', 'hourly.terrestrial_radiation', 'hourly.shortwave_radiation_instant', 'hourly.direct_radiation_instant', 'hourly.diffuse_radiation_instant', 'hourly.direct_normal_irradiance_instant', 'hourly.global_tilted_irradiance_instant', 'hourly.terrestrial_radiation_instant']
# ['hourly.shortwave_radiation', 'hourly.direct_radiation', 'hourly.diffuse_radiation', 'hourly.direct_normal_irradiance', 'hourly.global_tilted_irradiance', 'hourly.terrestrial_radiation']
# set()

# %%
_year = 2005

df = pd.read_csv("b2005y.csv")

print(df.head())

dfsourcex = pd.read_csv(f'error_rows{_year}.csv')

for r in range(0, len(dfsourcex)):

    row = dfsourcex.iloc[r]


    print(row)

    DISTRICTO = row['distrito']
    CONCELHO = row['concelho']
    FREGUESIA = row['freguesia']
    LOCAL = row['local']
    LAT = row['LAT']
    _DATA = row['data_alerta']
    LON = row['LON']
    CAUSA = row['tipo_causa']
    ANO = row['ano']
    hora = row['hora_alerta']
    HORA = int(str(hora).split(":")[0])

    if pd.isna(LOCAL):
        LOCAL = 'NC'

    if pd.isna(CAUSA):
        CAUSA = 'NC'

    MeteorologyFile = False
    RadiationFile = False


    _fileName = _DATA + f"_{LAT}_{LON}.csv"
    _fileName_radiation = _DATA + f"_{LAT}_{LON}_radiation.csv"

    print(_fileName, _fileName_radiation)

    # MissingFiles{_year}/{_fileName_radiation}.csv
    isExistMeteorology = os.path.isfile(f'MissingFiles{_year}/{_fileName}')
    if(isExistMeteorology):
        MeteorologyFile = True
    else:
        row_df = pd.DataFrame(row).transpose()  # Convert row (Series) to DataFrame
        row_df.to_csv(f'error_rowsX{_year}.csv', mode='a', header=False, index=False)
        
        continue

    isExistRadiation = os.path.isfile(f'MissingFiles{_year}/{_fileName_radiation}')
    if(isExistRadiation):
        RadiationFile = True
    else:
        row_df = pd.DataFrame(row).transpose()  # Convert row (Series) to DataFrame
        row_df.to_csv(f'error_rowsX{_year}.csv', mode='a', header=False, index=False)
        
        continue

    print(isExistMeteorology, RadiationFile)

    if(MeteorologyFile and RadiationFile):
        try:
            dfMet = pd.read_csv(f"MissingFiles{_year}/{_fileName}")
            dfRad = pd.read_csv(f"MissingFiles{_year}/{_fileName_radiation}")
        except Exception as e:
            print(e)
            row_df = pd.DataFrame(row).transpose()  # Convert row (Series) to DataFrame
            row_df.to_csv(f'error_rowsX{_year}.csv', mode='a', header=False, index=False)
            
            continue

        print(dfMet['elevation'].iloc[0])

        list_from_string = ast.literal_eval(dfMet[updated_column_names[2]].iloc[0])[HORA]

        print(list_from_string)

        list_from_string = ast.literal_eval(dfMet[updated_column_names[1]].iloc[0])[HORA]

        print(list_from_string)

        new_data = {
            'year': ANO,
            'date': f"{_DATA}",
            'district': DISTRICTO,
            'municipality': CONCELHO,
            'parish': FREGUESIA,
            'local': LOCAL,
            'latitude': LAT,
            'longitude': LON,
            'cause': CAUSA,
            'elevation': dfMet['elevation'].iloc[0]
        }

        try:
            for i in range(1, len(updated_column_names)):
                new_data[updated_column_names[i]] = ast.literal_eval(dfMet[updated_column_names[i]].iloc[0])[HORA]
        except Exception as e:
            print("->", e)

        try:
            for i in range(0, len(updated_column_names_radiation)):
                new_data[updated_column_names_radiation[i]] = ast.literal_eval(dfRad[updated_column_names_radiation[i]].iloc[0])[HORA]
        except Exception as e:
            print("-x", e)

        new_df = pd.DataFrame(new_data, index=[0])

        new_df.to_csv('b2005y.csv', mode='a', header=False, index=False)
# Out:
# Empty DataFrame
# Columns: [year, date, district, municipality, parish, local, latitude, longitude, cause, elevation, hourly.time, hourly.temperature_2m, hourly.relative_humidity_2m, hourly.dew_point_2m, hourly.apparent_temperature, hourly.precipitation, hourly.rain, hourly.snowfall, hourly.snow_depth, hourly.weather_code, hourly.pressure_msl, hourly.surface_pressure, hourly.cloud_cover, hourly.cloud_cover_low, hourly.cloud_cover_mid, hourly.cloud_cover_high, hourly.et0_fao_evapotranspiration, hourly.vapour_pressure_deficit, hourly.wind_speed_10m, hourly.wind_speed_100m, hourly.wind_direction_10m, hourly.wind_direction_100m, hourly.wind_gusts_10m, hourly.soil_temperature_0_to_7cm, hourly.soil_temperature_7_to_28cm, hourly.soil_temperature_28_to_100cm, hourly.soil_temperature_100_to_255cm, hourly.soil_moisture_0_to_7cm, hourly.soil_moisture_7_to_28cm, hourly.soil_moisture_28_to_100cm, hourly.soil_moisture_100_to_255cm, hourly.is_day, hourly.sunshine_duration, hourly.shortwave_radiation_instant, hourly.direct_radiation_instant, hourly.diffuse_radiation_instant, hourly.direct_normal_irradiance_instant, hourly.global_tilted_irradiance_instant, hourly.terrestrial_radiation_instant, hourly.shortwave_radiation, hourly.direct_radiation, hourly.diffuse_radiation, hourly.direct_normal_irradiance, hourly.global_tilted_irradiance, hourly.terrestrial_radiation]
# Index: []
#
# [0 rows x 55 columns]
# ano                                          2005
# codigo_sgif                             BI1051147
# tipo                                    Florestal
# distrito                                   Guarda
# concelho                     Vila Nova de Foz Côa
# freguesia                                   Touça
# local                              Serra da Touca
# ine                                         91416
# x                                        275565.0
# y                                        453242.0
# data_alerta                            2005-08-25
# hora_alerta                              14:45:00
# data_extincao                          2005-08-25
# hora_extincao                            18:00:00
# data_primeira_intervencao                     NaN
# hora_primeira_intervencao                     NaN
# fonte_alerta                                   PV
# nut                                    PT11071816
# area_povoamento                               0.0
# area_mato                                     3.0
# area_agricola                                 0.0
# area_pov_mato                                 3.0
# area_total                                    3.0
# reacendimento                                   0
# queimada                                        0
# falso_alarme                                    0
# fogacho                                         0
# incendio                                        1
# agricola                                        0
# perimetro                                     NaN
# aps                                           NaN
# causa                                         NaN
# tipo_causa                                    NaN
# LAT                                     41.047207
# LON                                     -7.234384
# Name: 0, dtype: object
# 2005-08-25_41.0472072_-7.2343843.csv 2005-08-25_41.0472072_-7.2343843_radiation.csv
# True True
# 610.0
# 29.7
# 2005-08-25T14:00
# ano                                 2005
# codigo_sgif                    BL1052539
# tipo                           Florestal
# distrito                           Viseu
# concelho                       Mangualde
# freguesia                      Mangualde
# local                        Santa Luzia
# ine                               180610
# x                               229513.0
# y                               402131.0
# data_alerta                   2005-08-06
# hora_alerta                     08:30:00
# data_extincao                 2005-08-06
# hora_extincao                   17:15:00
# data_primeira_intervencao     2005-08-06
# hora_primeira_intervencao       08:42:00
# fonte_alerta                   Populares
# nut                           PT12050410
# area_povoamento                      0.0
# area_mato                            0.5
# area_agricola                        0.0
# area_pov_mato                        0.5
# area_total                           0.5
# reacendimento                          0
# queimada                               0
# falso_alarme                           0
# fogacho                                1
# incendio                               0
# agricola                               0
# perimetro                            NaN
# aps                                  NaN
# causa                                NaN
# tipo_causa                           NaN
# LAT                            40.587657
# LON                            -7.784631
# Name: 1, dtype: object
# 2005-08-06_40.5876571_-7.7846306.csv 2005-08-06_40.5876571_-7.7846306_radiation.csv
# True True
# 445.0
# 24.5
# 2005-08-06T08:00
# ano                                2005
# codigo_sgif                   BL1054100
# tipo                          Florestal
# distrito                          Viseu
# concelho                        Cinfães
# freguesia                       Tendais
# local                          Meridãos
# ine                              180416
# x                              206351.0
# y                              449558.0
# data_alerta                  2005-10-03
# hora_alerta                    11:45:00
# data_extincao                2005-10-03
# hora_extincao                  22:20:00
# data_primeira_intervencao    2005-10-03
# hora_primeira_intervencao      11:56:00
# fonte_alerta                  Populares
# nut                          PT11050616
# area_povoamento                     0.0
# area_mato                           5.0
# area_agricola                       0.0
# area_pov_mato                       5.0
# area_total                          5.0
# reacendimento                         0
# queimada                              0
# falso_alarme                          0
# fogacho                               0
# incendio                              1
# agricola                              0
# perimetro                           NaN
# aps                                 NaN
# causa                               NaN
# tipo_causa                          NaN
# LAT                           41.012578
# LON                           -8.051263
# Name: 2, dtype: object
# 2005-10-03_41.0125776_-8.051263077789546.csv 2005-10-03_41.0125776_-8.051263077789546_radiation.csv
# True True
# 647.0
# 17.9
# 2005-10-03T11:00
# ano                                2005
# codigo_sgif                   BL1054095
# tipo                          Florestal
# distrito                          Viseu
# concelho                        Cinfães
# freguesia                       Tendais
# local                           TENDAIS
# ine                              180416
# x                              206920.0
# y                              449330.0
# data_alerta                  2005-10-03
# hora_alerta                    08:48:00
# data_extincao                2005-10-03
# hora_extincao                  21:45:00
# data_primeira_intervencao    2005-10-03
# hora_primeira_intervencao      11:30:00
# fonte_alerta                         PV
# nut                          PT11050616
# area_povoamento                     5.5
# area_mato                           0.0
# area_agricola                       0.0
# area_pov_mato                       5.5
# area_total                          5.5
# reacendimento                         0
# queimada                              0
# falso_alarme                          0
# fogacho                               0
# incendio                              1
# agricola                              0
# perimetro                           NaN
# aps                                 NaN
# causa                               NaN
# tipo_causa                          NaN
# LAT                           41.012578
# LON                           -8.051263
# Name: 3, dtype: object
# 2005-10-03_41.0125776_-8.051263077789546.csv 2005-10-03_41.0125776_-8.051263077789546_radiation.csv
# True True
# 647.0
# 11.9
# 2005-10-03T08:00
# ano                                      2005
# codigo_sgif                         BL3054496
# tipo                                Florestal
# distrito                               Aveiro
# concelho                     Castelo de Paiva
# freguesia                            Pedorido
# local                                   Póvoa
# ine                                     10604
# x                                    178547.0
# y                                    452373.0
# data_alerta                        2005-09-27
# hora_alerta                          07:05:00
# data_extincao                      2005-09-27
# hora_extincao                        14:45:00
# data_primeira_intervencao                 NaN
# hora_primeira_intervencao                 NaN
# fonte_alerta                        Populares
# nut                                PT11050404
# area_povoamento                           0.0
# area_mato                                 0.7
# area_agricola                             0.0
# area_pov_mato                             0.7
# area_total                                0.7
# reacendimento                               0
# queimada                                    0
# falso_alarme                                0
# fogacho                                     1
# incendio                                    0
# agricola                                    0
# perimetro                                 NaN
# aps                                       NaN
# causa                                     NaN
# tipo_causa                                NaN
# LAT                                 41.039135
# LON                                 -8.390775
# Name: 4, dtype: object
# 2005-09-27_41.0391345_-8.390774868553063.csv 2005-09-27_41.0391345_-8.390774868553063_radiation.csv
# True True
# 146.0
# 13.6
# 2005-09-27T07:00
# ano                                             2005
# codigo_sgif                                BL4051296
# tipo                                       Florestal
# distrito                                      Leiria
# concelho                                      Leiria
# freguesia                    Santa Catarina da Serra
# local                        Casal da Fonte da Pedra
# ine                                           100922
# x                                           155753.0
# y                                           300556.0
# data_alerta                               2005-09-10
# hora_alerta                                 08:56:00
# data_extincao                             2005-09-10
# hora_extincao                               09:40:00
# data_primeira_intervencao                        NaN
# hora_primeira_intervencao                        NaN
# fonte_alerta                               Populares
# nut                                       PT12030222
# area_povoamento                                  0.0
# area_mato                                      0.001
# area_agricola                                    0.0
# area_pov_mato                                  0.001
# area_total                                     0.001
# reacendimento                                      0
# queimada                                           0
# falso_alarme                                       0
# fogacho                                            1
# incendio                                           0
# agricola                                           0
# perimetro                                        NaN
# aps                                              NaN
# causa                                            NaN
# tipo_causa                                       NaN
# LAT                                        39.671083
# LON                                        -8.650322
# Name: 5, dtype: object
# 2005-09-10_39.6710831_-8.6503218.csv 2005-09-10_39.6710831_-8.6503218_radiation.csv
# True True
# 235.0
# 16.9
# 2005-09-10T08:00
# ano                                   2005
# codigo_sgif                      DM4052244
# tipo                             Florestal
# distrito                             Braga
# concelho                              Fafe
# freguesia                             Fafe
# local                        FONTE DA CANA
# ine                                  30709
# x                                 196887.0
# y                                 498468.0
# data_alerta                     2005-07-07
# hora_alerta                       13:13:00
# data_extincao                   2005-07-07
# hora_extincao                     14:15:00
# data_primeira_intervencao       2005-07-07
# hora_primeira_intervencao         13:25:00
# fonte_alerta                    Particular
# nut                             PT11030109
# area_povoamento                        0.0
# area_mato                             0.01
# area_agricola                          0.0
# area_pov_mato                         0.01
# area_total                            0.01
# reacendimento                            0
# queimada                                 0
# falso_alarme                             0
# fogacho                                  1
# incendio                                 0
# agricola                                 0
# perimetro                              NaN
# aps                                    NaN
# causa                                  NaN
# tipo_causa                             NaN
# LAT                              41.446873
# LON                              -8.180584
# Name: 6, dtype: object
# 2005-07-07_41.4468733_-8.180584376446348.csv 2005-07-07_41.4468733_-8.180584376446348_radiation.csv
# True True
# 343.0
# 28.8
# 2005-07-07T13:00
# ano                                            2005
# codigo_sgif                               DM4052367
# tipo                                      Florestal
# distrito                                      Braga
# concelho                     Vila Nova de Famalicão
# freguesia                                   Lousado
# local                             RUA CONEGO BORGES
# ine                                           31224
# x                                          166130.0
# y                                          486834.0
# data_alerta                              2005-07-09
# hora_alerta                                16:05:00
# data_extincao                            2005-07-09
# hora_extincao                              16:50:00
# data_primeira_intervencao                2005-07-09
# hora_primeira_intervencao                  16:17:00
# fonte_alerta                                    117
# nut                                      PT11030624
# area_povoamento                                 0.0
# area_mato                                     0.001
# area_agricola                                   0.0
# area_pov_mato                                 0.001
# area_total                                    0.001
# reacendimento                                     0
# queimada                                          0
# falso_alarme                                      0
# fogacho                                           1
# incendio                                          0
# agricola                                          0
# perimetro                                       NaN
# aps                                             NaN
# causa                                           NaN
# tipo_causa                                      NaN
# LAT                                       41.355265
# LON                                       -8.536757
# Name: 7, dtype: object
# 2005-07-09_41.3552648_-8.5367566.csv 2005-07-09_41.3552648_-8.5367566_radiation.csv
# True True
# 63.0
# 32.4
# 2005-07-09T16:00
# ano                                       2005
# codigo_sgif                          DM4052028
# tipo                                 Florestal
# distrito                                 Braga
# concelho                     Celorico de Basto
# freguesia                                Corgo
# local                                Vila Nova
# ine                                      30509
# x                                     211677.0
# y                                     497149.0
# data_alerta                         2005-06-23
# hora_alerta                           18:10:00
# data_extincao                       2005-06-23
# hora_extincao                         21:20:00
# data_primeira_intervencao           2005-06-23
# hora_primeira_intervencao             18:20:00
# fonte_alerta                               117
# nut                                 PT11050509
# area_povoamento                            1.0
# area_mato                                  2.0
# area_agricola                              0.0
# area_pov_mato                              3.0
# area_total                                 3.0
# reacendimento                                0
# queimada                                     0
# falso_alarme                                 0
# fogacho                                      0
# incendio                                     1
# agricola                                     0
# perimetro                                  NaN
# aps                                        NaN
# causa                                      NaN
# tipo_causa                                 NaN
# LAT                                  41.433803
# LON                                  -7.978644
# Name: 8, dtype: object
# 2005-06-23_41.4338033_-7.9786441.csv 2005-06-23_41.4338033_-7.9786441_radiation.csv
# True True
# 231.0
# 24.8
# 2005-06-23T18:00
# ano                                2005
# codigo_sgif                   DM4055245
# tipo                          Florestal
# distrito                          Braga
# concelho                           Fafe
# freguesia                      São Gens
# local                            Vilela
# ine                               30728
# x                              200484.0
# y                              493986.0
# data_alerta                  2005-09-22
# hora_alerta                    06:26:00
# data_extincao                2005-09-22
# hora_extincao                  07:50:00
# data_primeira_intervencao    2005-09-22
# hora_primeira_intervencao      06:45:00
# fonte_alerta                        117
# nut                          PT11030128
# area_povoamento                    0.02
# area_mato                           0.0
# area_agricola                       0.0
# area_pov_mato                      0.02
# area_total                         0.02
# reacendimento                         0
# queimada                              0
# falso_alarme                          0
# fogacho                               1
# incendio                              0
# agricola                              0
# perimetro                           NaN
# aps                                 NaN
# causa                               NaN
# tipo_causa                          NaN
# LAT                           41.462056
# LON                           -8.130802
# Name: 9, dtype: object
# 2005-09-22_41.462056200000006_-8.130801614145298.csv 2005-09-22_41.462056200000006_-8.130801614145298_radiation.csv
# True True
# 411.0
# 12.5
# 2005-09-22T06:00
# ano                                         2005
# codigo_sgif                            RO2052607
# tipo                                   Florestal
# distrito                                  Lisboa
# concelho                                  Sintra
# freguesia                    São João das Lampas
# local                                   AMOREIRA
# ine                                       111110
# x                                        91309.0
# y                                       213575.0
# data_alerta                           2005-07-26
# hora_alerta                             17:14:00
# data_extincao                         2005-07-26
# hora_extincao                           21:25:00
# data_primeira_intervencao                    NaN
# hora_primeira_intervencao                    NaN
# fonte_alerta                           Populares
# nut                                   PT13020610
# area_povoamento                              0.0
# area_mato                                    1.0
# area_agricola                                0.0
# area_pov_mato                                1.0
# area_total                                   1.0
# reacendimento                                  0
# queimada                                       0
# falso_alarme                                   0
# fogacho                                        0
# incendio                                       1
# agricola                                       0
# perimetro                                    NaN
# aps                                          NaN
# causa                                        NaN
# tipo_causa                                   NaN
# LAT                                    38.833632
# LON                                    -9.367501
# Name: 10, dtype: object
# 2005-07-26_38.83363195_-9.367501448128994.csv 2005-07-26_38.83363195_-9.367501448128994_radiation.csv
# True True
# 159.0
# 21.2
# 2005-07-26T17:00
# ano                                         2005
# codigo_sgif                            RO2052598
# tipo                                   Florestal
# distrito                                  Lisboa
# concelho                                  Sintra
# freguesia                    São João das Lampas
# local                                   AMOREIRA
# ine                                       111110
# x                                        91309.0
# y                                       213575.0
# data_alerta                           2005-07-26
# hora_alerta                             07:29:00
# data_extincao                         2005-07-26
# hora_extincao                           09:50:00
# data_primeira_intervencao                    NaN
# hora_primeira_intervencao                    NaN
# fonte_alerta                                 CCO
# nut                                   PT13020610
# area_povoamento                              0.0
# area_mato                                  0.005
# area_agricola                                0.0
# area_pov_mato                              0.005
# area_total                                 0.005
# reacendimento                                  0
# queimada                                       0
# falso_alarme                                   0
# fogacho                                        1
# incendio                                       0
# agricola                                       0
# perimetro                                    NaN
# aps                                          NaN
# causa                                        NaN
# tipo_causa                                   NaN
# LAT                                    38.833632
# LON                                    -9.367501
# Name: 11, dtype: object
# 2005-07-26_38.83363195_-9.367501448128994.csv 2005-07-26_38.83363195_-9.367501448128994_radiation.csv
# True True
# 159.0
# 19.3
# 2005-07-26T07:00
# ano                                                2005
# codigo_sgif                                   RO2052596
# tipo                                          Florestal
# distrito                                         Lisboa
# concelho                                         Sintra
# freguesia                           São João das Lampas
# local                        AMOREIRA JTO DEPOSITO AGUA
# ine                                              111110
# x                                               91309.0
# y                                              213575.0
# data_alerta                                  2005-07-26
# hora_alerta                                    03:35:00
# data_extincao                                2005-07-26
# hora_extincao                                  04:40:00
# data_primeira_intervencao                           NaN
# hora_primeira_intervencao                           NaN
# fonte_alerta                                        CCO
# nut                                          PT13020610
# area_povoamento                                     0.0
# area_mato                                         0.005
# area_agricola                                       0.0
# area_pov_mato                                     0.005
# area_total                                        0.005
# reacendimento                                         0
# queimada                                              0
# falso_alarme                                          0
# fogacho                                               1
# incendio                                              0
# agricola                                              0
# perimetro                                           NaN
# aps                                                 NaN
# causa                                               NaN
# tipo_causa                                          NaN
# LAT                                           38.833632
# LON                                           -9.367501
# Name: 12, dtype: object
# 2005-07-26_38.83363195_-9.367501448128994.csv 2005-07-26_38.83363195_-9.367501448128994_radiation.csv
# True True
# 159.0
# 18.8
# 2005-07-26T03:00
# ano                                         2005
# codigo_sgif                            RO2052605
# tipo                                   Florestal
# distrito                                  Lisboa
# concelho                                  Sintra
# freguesia                    São João das Lampas
# local                                   AMOREIRA
# ine                                       111110
# x                                        91309.0
# y                                       213575.0
# data_alerta                           2005-07-26
# hora_alerta                             10:54:00
# data_extincao                         2005-07-26
# hora_extincao                           14:00:00
# data_primeira_intervencao                    NaN
# hora_primeira_intervencao                    NaN
# fonte_alerta                           Populares
# nut                                   PT13020610
# area_povoamento                              0.0
# area_mato                                   0.03
# area_agricola                                0.0
# area_pov_mato                               0.03
# area_total                                  0.03
# reacendimento                                  0
# queimada                                       0
# falso_alarme                                   0
# fogacho                                        1
# incendio                                       0
# agricola                                       0
# perimetro                                    NaN
# aps                                          NaN
# causa                                        NaN
# tipo_causa                                   NaN
# LAT                                    38.833632
# LON                                    -9.367501
# Name: 13, dtype: object
# 2005-07-26_38.83363195_-9.367501448128994.csv 2005-07-26_38.83363195_-9.367501448128994_radiation.csv
# True True
# 159.0
# 20.6
# 2005-07-26T10:00
# ano                                         2005
# codigo_sgif                            RO2052670
# tipo                                   Florestal
# distrito                                  Lisboa
# concelho                     Vila Franca de Xira
# freguesia                          Forte da Casa
# local                            EN-10 (JNT ABP)
# ine                                       111411
# x                                       119781.0
# y                                       212192.0
# data_alerta                           2005-07-31
# hora_alerta                             11:35:00
# data_extincao                         2005-07-31
# hora_extincao                           12:30:00
# data_primeira_intervencao                    NaN
# hora_primeira_intervencao                    NaN
# fonte_alerta                              Outros
# nut                                   PT13020711
# area_povoamento                              0.0
# area_mato                                   0.01
# area_agricola                                0.0
# area_pov_mato                               0.01
# area_total                                  0.01
# reacendimento                                  0
# queimada                                       0
# falso_alarme                                   0
# fogacho                                        1
# incendio                                       0
# agricola                                       0
# perimetro                                    NaN
# aps                                          NaN
# causa                                        NaN
# tipo_causa                                   NaN
# LAT                                    38.872784
# LON                                    -9.059316
# Name: 14, dtype: object
# 2005-07-31_38.8727839_-9.0593162.csv 2005-07-31_38.8727839_-9.0593162_radiation.csv
# True True
# 32.0
# 25.2
# 2005-07-31T11:00
# ano                                2005
# codigo_sgif                    RO205300
# tipo                          Florestal
# distrito                         Lisboa
# concelho                       Azambuja
# freguesia                     Alcoentre
# local                           TAGARRO
# ine                              110301
# x                              126477.0
# y                              251720.0
# data_alerta                  2005-02-01
# hora_alerta                    21:10:00
# data_extincao                2005-02-01
# hora_extincao                  22:00:00
# data_primeira_intervencao           NaN
# hora_primeira_intervencao           NaN
# fonte_alerta                  Populares
# nut                          PT13050301
# area_povoamento                     0.0
# area_mato                          0.01
# area_agricola                       0.0
# area_pov_mato                      0.01
# area_total                         0.01
# reacendimento                         0
# queimada                              0
# falso_alarme                          0
# fogacho                               1
# incendio                              0
# agricola                              0
# perimetro                           NaN
# aps                                 NaN
# causa                               NaN
# tipo_causa                          NaN
# LAT                           39.207826
# LON                           -8.957236
# Name: 15, dtype: object
# 2005-02-01_39.2078257_-8.9572359.csv 2005-02-01_39.2078257_-8.9572359_radiation.csv
# True True
# 81.0
# 7.8
# 2005-02-01T21:00
# ano                                         2005
# codigo_sgif                            RO2052611
# tipo                                   Florestal
# distrito                                  Lisboa
# concelho                                  Sintra
# freguesia                    São João das Lampas
# local                                   AMOREIRA
# ine                                       111110
# x                                        91309.0
# y                                       213575.0
# data_alerta                           2005-07-26
# hora_alerta                             23:34:00
# data_extincao                         2005-07-27
# hora_extincao                           01:15:00
# data_primeira_intervencao                    NaN
# hora_primeira_intervencao                    NaN
# fonte_alerta                           Populares
# nut                                   PT13020610
# area_povoamento                              0.0
# area_mato                                   0.01
# area_agricola                                0.0
# area_pov_mato                               0.01
# area_total                                  0.01
# reacendimento                                  0
# queimada                                       0
# falso_alarme                                   0
# fogacho                                        1
# incendio                                       0
# agricola                                       0
# perimetro                                    NaN
# aps                                          NaN
# causa                                        NaN
# tipo_causa                                   NaN
# LAT                                    38.833632
# LON                                    -9.367501
# Name: 16, dtype: object
# 2005-07-26_38.83363195_-9.367501448128994.csv 2005-07-26_38.83363195_-9.367501448128994_radiation.csv
# True True
# 159.0
# 19.5
# 2005-07-26T23:00
