# %%
import pandas as pd
import requests
import ast
import os
# Out:
# /tmp/ipykernel_3775/1817075740.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
import pandas as pd
_year = 2009
dfMissing = pd.read_csv(f'error_rows{_year}.csv')
print(len(dfMissing))
# Out:
# 13

# %%
print(len([f for f in os.listdir(f'MissingFiles{_year}') if os.path.isfile(os.path.join(f'MissingFiles{_year}', f))]))
# Out:
# 0

# %%
_year = 2008
dfMissing = pd.read_csv(f'error_rows{_year}.csv')
print(len(dfMissing))
for r in range(0, len(dfMissing)):
    row = dfMissing.iloc[r]

    LAT = row['LAT']
    _DATA = row['data_alerta']
    LON = row['LON']

    _fileName_radiation = _DATA + f"_{LAT}_{LON}_radiation"
    _fileName = _DATA + f"_{LAT}_{LON}"


    #RawData/RawDataAnalysis/MissingFiles2012
    url_rad = f"https://archive-api.open-meteo.com/v1/archive?latitude={LAT}&longitude={LON}&start_date={_DATA}&end_date={_DATA}&hourly=shortwave_radiation,direct_radiation,diffuse_radiation,direct_normal_irradiance,global_tilted_irradiance,terrestrial_radiation,shortwave_radiation_instant,direct_radiation_instant,diffuse_radiation_instant,direct_normal_irradiance_instant,global_tilted_irradiance_instant,terrestrial_radiation_instant"
    #url = f"https://archive-api.open-meteo.com/v1/archive?latitude={LAT}&longitude={LON}&start_date={_DATA}&end_date={_DATA}&hourly=temperature_2m,relative_humidity_2m,dew_point_2m,apparent_temperature,precipitation,rain,snowfall,snow_depth,weather_code,pressure_msl,surface_pressure,cloud_cover,cloud_cover_low,cloud_cover_mid,cloud_cover_high,et0_fao_evapotranspiration,vapour_pressure_deficit,wind_speed_10m,wind_speed_100m,wind_direction_10m,wind_direction_100m,wind_gusts_10m,soil_temperature_0_to_7cm,soil_temperature_7_to_28cm,soil_temperature_28_to_100cm,soil_temperature_100_to_255cm,soil_moisture_0_to_7cm,soil_moisture_7_to_28cm,soil_moisture_28_to_100cm,soil_moisture_100_to_255cm,is_day,sunshine_duration,shortwave_radiation_instant,direct_radiation_instant,diffuse_radiation_instant,direct_normal_irradiance_instant,global_tilted_irradiance_instant,terrestrial_radiation_instant&timezone=GMT"
    #response = requests.get(url)
    response_rad = requests.get(url_rad)

    #print(response.status_code)
    print(response_rad.status_code)

    if((response_rad.status_code == 200)):
        #data = response.json()
        data_rad = response_rad.json()

        #df = pd.json_normalize(data)
        #df.to_csv(f"MissingFiles{_year}/{_fileName}.csv", index=False)

        df_rad = pd.json_normalize(data_rad)
        df_rad.to_csv(f"MissingFiles{_year}/{_fileName_radiation}.csv", index=False)
    else:
        print("Error row:", str(r))
# Out:
# 7
# 200
# 200
# 200
# 200
# 200
# 200
# 200

# %%
current_dir = os.getcwd()
root_dir = os.path.dirname(os.path.dirname(current_dir))
_RAWFIRESPATH = f"{root_dir}/RawData/Historical_FiresRAW"

_year = 2005
_file = f"{_RAWFIRESPATH}/{_year}/2005-01-01_37.7388357_-8.750062888101874.csv"
df = pd.read_csv(f"{_file}")

column_names = df.columns.tolist()

column_names = df.columns.tolist()

columns_to_remove = [col for col in column_names if 'hourly_units' in col]
columns_to_remove.extend(['latitude', 'longitude', 'generationtime_ms', 'utc_offset_seconds', 'timezone', 'timezone_abbreviation'])

df = df.drop(columns=columns_to_remove)

updated_column_names = df.columns.tolist()

_file_radiation = _file.replace(".csv", "_radiation.csv")
df = pd.read_csv(f"{_file_radiation}")

df = pd.read_csv(f"{_file_radiation}")
column_names = df.columns.tolist()
print(column_names)

column_names = df.columns.tolist()

columns_to_remove = [col for col in column_names if 'hourly_units' in col]
columns_to_remove.extend(['latitude', 'longitude', 'generationtime_ms', 'utc_offset_seconds', 'timezone', 'timezone_abbreviation', 'elevation', 'hourly.time', 'hourly.global_tilted_irradiance_instant', 'hourly.diffuse_radiation_instant', 'hourly.terrestrial_radiation_instant', 'hourly.direct_radiation_instant', 'hourly.shortwave_radiation_instant', 'hourly.direct_normal_irradiance_instant'])

df = df.drop(columns=columns_to_remove)

updated_column_names_radiation = df.columns.tolist()
print(updated_column_names_radiation)

set1 = set(updated_column_names_radiation)
set2 = set(updated_column_names)

common_elements = set1 & set2

print(common_elements)
# Out:
# ['latitude', 'longitude', 'generationtime_ms', 'utc_offset_seconds', 'timezone', 'timezone_abbreviation', 'elevation', 'hourly_units.time', 'hourly_units.shortwave_radiation', 'hourly_units.direct_radiation', 'hourly_units.diffuse_radiation', 'hourly_units.direct_normal_irradiance', 'hourly_units.global_tilted_irradiance', 'hourly_units.terrestrial_radiation', 'hourly_units.shortwave_radiation_instant', 'hourly_units.direct_radiation_instant', 'hourly_units.diffuse_radiation_instant', 'hourly_units.direct_normal_irradiance_instant', 'hourly_units.global_tilted_irradiance_instant', 'hourly_units.terrestrial_radiation_instant', 'hourly.time', 'hourly.shortwave_radiation', 'hourly.direct_radiation', 'hourly.diffuse_radiation', 'hourly.direct_normal_irradiance', 'hourly.global_tilted_irradiance', 'hourly.terrestrial_radiation', 'hourly.shortwave_radiation_instant', 'hourly.direct_radiation_instant', 'hourly.diffuse_radiation_instant', 'hourly.direct_normal_irradiance_instant', 'hourly.global_tilted_irradiance_instant', 'hourly.terrestrial_radiation_instant']
# ['hourly.shortwave_radiation', 'hourly.direct_radiation', 'hourly.diffuse_radiation', 'hourly.direct_normal_irradiance', 'hourly.global_tilted_irradiance', 'hourly.terrestrial_radiation']
# set()

# %%
_year = 2008

df = pd.read_csv("b2008y.csv")

print(df.head())

dfsourcex = pd.read_csv(f'error_rows{_year}.csv')

for r in range(0, len(dfsourcex)):

    row = dfsourcex.iloc[r]


    print(row)

    DISTRICTO = row['distrito']
    CONCELHO = row['concelho']
    FREGUESIA = row['freguesia']
    LOCAL = row['local']
    LAT = row['LAT']
    _DATA = row['data_alerta']
    LON = row['LON']
    CAUSA = row['tipo_causa']
    ANO = row['ano']
    hora = row['hora_alerta']
    HORA = int(str(hora).split(":")[0])

    if pd.isna(LOCAL):
        LOCAL = 'NC'

    if pd.isna(CAUSA):
        CAUSA = 'NC'

    MeteorologyFile = False
    RadiationFile = False


    _fileName = _DATA + f"_{LAT}_{LON}.csv"
    _fileName_radiation = _DATA + f"_{LAT}_{LON}_radiation.csv"

    print(_fileName, _fileName_radiation)

    # MissingFiles{_year}/{_fileName_radiation}.csv
    isExistMeteorology = os.path.isfile(f'MissingFiles{_year}/{_fileName}')
    if(isExistMeteorology):
        MeteorologyFile = True
    else:
        row_df = pd.DataFrame(row).transpose()  # Convert row (Series) to DataFrame
        row_df.to_csv(f'error_rowsX{_year}.csv', mode='a', header=False, index=False)
        
        continue

    isExistRadiation = os.path.isfile(f'MissingFiles{_year}/{_fileName_radiation}')
    if(isExistRadiation):
        RadiationFile = True
    else:
        row_df = pd.DataFrame(row).transpose()  # Convert row (Series) to DataFrame
        row_df.to_csv(f'error_rowsX{_year}.csv', mode='a', header=False, index=False)
        
        continue

    print(isExistMeteorology, RadiationFile)

    if(MeteorologyFile and RadiationFile):
        try:
            dfMet = pd.read_csv(f"MissingFiles{_year}/{_fileName}")
            dfRad = pd.read_csv(f"MissingFiles{_year}/{_fileName_radiation}")
        except Exception as e:
            print(e)
            row_df = pd.DataFrame(row).transpose()  # Convert row (Series) to DataFrame
            row_df.to_csv(f'error_rowsX{_year}.csv', mode='a', header=False, index=False)
            
            continue

        print(dfMet['elevation'].iloc[0])

        list_from_string = ast.literal_eval(dfMet[updated_column_names[2]].iloc[0])[HORA]

        print(list_from_string)

        list_from_string = ast.literal_eval(dfMet[updated_column_names[1]].iloc[0])[HORA]

        print(list_from_string)

        new_data = {
            'year': ANO,
            'date': f"{_DATA}",
            'district': DISTRICTO,
            'municipality': CONCELHO,
            'parish': FREGUESIA,
            'local': LOCAL,
            'latitude': LAT,
            'longitude': LON,
            'cause': CAUSA,
            'elevation': dfMet['elevation'].iloc[0]
        }

        try:
            for i in range(1, len(updated_column_names)):
                new_data[updated_column_names[i]] = ast.literal_eval(dfMet[updated_column_names[i]].iloc[0])[HORA]
        except Exception as e:
            print("->", e)

        try:
            for i in range(0, len(updated_column_names_radiation)):
                new_data[updated_column_names_radiation[i]] = ast.literal_eval(dfRad[updated_column_names_radiation[i]].iloc[0])[HORA]
        except Exception as e:
            print("-x", e)

        new_df = pd.DataFrame(new_data, index=[0])

        new_df.to_csv('b2008y.csv', mode='a', header=False, index=False)
# Out:
# Empty DataFrame
# Columns: [year, date, district, municipality, parish, local, latitude, longitude, cause, elevation, hourly.time, hourly.temperature_2m, hourly.relative_humidity_2m, hourly.dew_point_2m, hourly.apparent_temperature, hourly.precipitation, hourly.rain, hourly.snowfall, hourly.snow_depth, hourly.weather_code, hourly.pressure_msl, hourly.surface_pressure, hourly.cloud_cover, hourly.cloud_cover_low, hourly.cloud_cover_mid, hourly.cloud_cover_high, hourly.et0_fao_evapotranspiration, hourly.vapour_pressure_deficit, hourly.wind_speed_10m, hourly.wind_speed_100m, hourly.wind_direction_10m, hourly.wind_direction_100m, hourly.wind_gusts_10m, hourly.soil_temperature_0_to_7cm, hourly.soil_temperature_7_to_28cm, hourly.soil_temperature_28_to_100cm, hourly.soil_temperature_100_to_255cm, hourly.soil_moisture_0_to_7cm, hourly.soil_moisture_7_to_28cm, hourly.soil_moisture_28_to_100cm, hourly.soil_moisture_100_to_255cm, hourly.is_day, hourly.sunshine_duration, hourly.shortwave_radiation_instant, hourly.direct_radiation_instant, hourly.diffuse_radiation_instant, hourly.direct_normal_irradiance_instant, hourly.global_tilted_irradiance_instant, hourly.terrestrial_radiation_instant, hourly.shortwave_radiation, hourly.direct_radiation, hourly.diffuse_radiation, hourly.direct_normal_irradiance, hourly.global_tilted_irradiance, hourly.terrestrial_radiation]
# Index: []
#
# [0 rows x 55 columns]
# ano                                  2009
# codigo_sgif                     BL1091201
# tipo                            Florestal
# distrito                            Viseu
# concelho                     Castro Daire
# freguesia                          Ermida
# local                          Sobradinho
# ine                                180306
# x                                  213747
# y                                  440420
# data_alerta                    2009-06-02
# hora_alerta                      03:50:00
# data_extincao                  2009-06-02
# hora_extincao                    10:38:00
# data_primeira_intervencao      2009-06-02
# hora_primeira_intervencao        04:00:00
# fonte_alerta                    Populares
# nut                            PT12050306
# area_povoamento                       0.0
# area_mato                            0.01
# area_agricola                         0.0
# area_pov_mato                        0.01
# area_total                           0.01
# reacendimento                           1
# queimada                                0
# falso_alarme                            0
# fogacho                                 1
# incendio                                0
# agricola                                0
# perimetro                             NaN
# aps                                   NaN
# causa                                 6.0
# tipo_causa                   Desconhecida
# LAT                             40.921251
# LON                             -7.968118
# Name: 0, dtype: object
# 2009-06-02_40.9212513_-7.968118.csv 2009-06-02_40.9212513_-7.968118_radiation.csv
# True True
# 397.0
# 15.7
# 2009-06-02T03:00
# ano                                  2009
# codigo_sgif                      BL309312
# tipo                            Florestal
# distrito                           Aveiro
# concelho                           Arouca
# freguesia                         Fermedo
# local                           Parameira
# ine                                 10411
# x                                  176898
# y                                  443366
# data_alerta                    2009-03-25
# hora_alerta                      00:35:00
# data_extincao                  2009-03-25
# hora_extincao                    02:45:00
# data_primeira_intervencao      2009-03-25
# hora_primeira_intervencao        00:46:00
# fonte_alerta                    Populares
# nut                            PT11060111
# area_povoamento                       0.0
# area_mato                            0.35
# area_agricola                         0.0
# area_pov_mato                        0.35
# area_total                           0.35
# reacendimento                           0
# queimada                                0
# falso_alarme                            0
# fogacho                                 1
# incendio                                0
# agricola                                0
# perimetro                             NaN
# aps                                   NaN
# causa                                 6.0
# tipo_causa                   Desconhecida
# LAT                             40.953162
# LON                             -8.428823
# Name: 1, dtype: object
# 2009-03-25_40.9531619_-8.428823.csv 2009-03-25_40.9531619_-8.428823_radiation.csv
# True True
# 350.0
# 9.1
# 2009-03-25T00:00
# ano                                            2009
# codigo_sgif                               DM2091604
# tipo                                      Florestal
# distrito                                      Porto
# concelho                          Paços de Ferreira
# freguesia                                  Ferreira
# local                        S. MIGUEL (São Miguel)
# ine                                          130905
# x                                            182624
# y                                            477746
# data_alerta                              2009-06-01
# hora_alerta                                15:16:00
# data_extincao                            2009-06-01
# hora_extincao                              16:18:00
# data_primeira_intervencao                2009-06-01
# hora_primeira_intervencao                  15:21:00
# fonte_alerta                                    117
# nut                                      PT11051105
# area_povoamento                                 0.0
# area_mato                                      0.01
# area_agricola                                   0.0
# area_pov_mato                                  0.01
# area_total                                     0.01
# reacendimento                                     0
# queimada                                          0
# falso_alarme                                      0
# fogacho                                           1
# incendio                                          0
# agricola                                          0
# perimetro                                       NaN
# aps                                             NaN
# causa                                           NaN
# tipo_causa                                      NaN
# LAT                                        41.27615
# LON                                       -8.377378
# Name: 2, dtype: object
# 2009-06-01_41.2761505_-8.3773783.csv 2009-06-01_41.2761505_-8.3773783_radiation.csv
# True True
# 305.0
# 27.3
# 2009-06-01T15:00
# ano                                             2009
# codigo_sgif                                DM2092894
# tipo                                       Florestal
# distrito                                       Porto
# concelho                                     Paredes
# freguesia                                    Lordelo
# local                        LUGAR LEVADINHA (Lugar)
# ine                                           131013
# x                                             184157
# y                                             474866
# data_alerta                               2009-08-11
# hora_alerta                                 15:14:00
# data_extincao                             2009-08-11
# hora_extincao                               16:37:00
# data_primeira_intervencao                 2009-08-11
# hora_primeira_intervencao                   15:18:00
# fonte_alerta                               Populares
# nut                                       PT11051213
# area_povoamento                                  0.0
# area_mato                                       0.05
# area_agricola                                    0.0
# area_pov_mato                                   0.05
# area_total                                      0.05
# reacendimento                                      0
# queimada                                           0
# falso_alarme                                       0
# fogacho                                            1
# incendio                                           0
# agricola                                           0
# perimetro                                        NaN
# aps                                              NaN
# causa                                            NaN
# tipo_causa                                       NaN
# LAT                                        41.236497
# LON                                        -8.415552
# Name: 3, dtype: object
# 2009-08-11_41.2364966_-8.415551743176014.csv 2009-08-11_41.2364966_-8.415551743176014_radiation.csv
# True True
# 210.0
# 31.2
# 2009-08-11T15:00
# ano                                            2009
# codigo_sgif                               DM2092908
# tipo                                      Florestal
# distrito                                      Porto
# concelho                                    Paredes
# freguesia                                   Lordelo
# local                        LEVADINHA (Levandeira)
# ine                                          131013
# x                                            181616
# y                                            469473
# data_alerta                              2009-08-11
# hora_alerta                                18:36:00
# data_extincao                            2009-08-11
# hora_extincao                              19:36:00
# data_primeira_intervencao                2009-08-11
# hora_primeira_intervencao                  18:40:00
# fonte_alerta                              Populares
# nut                                      PT11051213
# area_povoamento                                 0.0
# area_mato                                      0.05
# area_agricola                                   0.0
# area_pov_mato                                  0.05
# area_total                                     0.05
# reacendimento                                     0
# queimada                                          0
# falso_alarme                                      0
# fogacho                                           1
# incendio                                          0
# agricola                                          0
# perimetro                                       NaN
# aps                                             NaN
# causa                                           NaN
# tipo_causa                                      NaN
# LAT                                       41.236497
# LON                                       -8.415552
# Name: 4, dtype: object
# 2009-08-11_41.2364966_-8.415551743176014.csv 2009-08-11_41.2364966_-8.415551743176014_radiation.csv
# True True
# 210.0
# 28.4
# 2009-08-11T18:00
# ano                                        2009
# codigo_sgif                           DM2096284
# tipo                                  Florestal
# distrito                                  Porto
# concelho                     Marco de Canaveses
# freguesia                       Rio de Galinhas
# local                                   Estação
# ine                                      130716
# x                                        198156
# y                                        471931
# data_alerta                          2009-09-19
# hora_alerta                            13:52:00
# data_extincao                        2009-09-19
# hora_extincao                          15:03:00
# data_primeira_intervencao            2009-09-19
# hora_primeira_intervencao              14:00:00
# fonte_alerta                          Populares
# nut                                  PT11050916
# area_povoamento                             0.0
# area_mato                                  0.01
# area_agricola                               0.0
# area_pov_mato                              0.01
# area_total                                 0.01
# reacendimento                                 0
# queimada                                      0
# falso_alarme                                  0
# fogacho                                       1
# incendio                                      0
# agricola                                      0
# perimetro                                   NaN
# aps                                         NaN
# causa                                       NaN
# tipo_causa                                  NaN
# LAT                                   41.186174
# LON                                   -8.138351
# Name: 5, dtype: object
# 2009-09-19_41.1861735_-8.1383514.csv 2009-09-19_41.1861735_-8.1383514_radiation.csv
# True True
# 110.0
# 20.1
# 2009-09-19T13:00
# ano                                                2009
# codigo_sgif                                   DM4091426
# tipo                                          Florestal
# distrito                                          Braga
# concelho                              Celorico de Basto
# freguesia                                        Arnóia
# local                        CASTELO (ARNOIA) (Castelo)
# ine                                               30502
# x                                                206633
# y                                                488346
# data_alerta                                  2009-07-21
# hora_alerta                                    22:35:00
# data_extincao                                2009-07-21
# hora_extincao                                  23:55:00
# data_primeira_intervencao                    2009-07-21
# hora_primeira_intervencao                      22:40:00
# fonte_alerta                                  Populares
# nut                                          PT11050502
# area_povoamento                                     0.0
# area_mato                                           0.1
# area_agricola                                       0.0
# area_pov_mato                                       0.1
# area_total                                          0.1
# reacendimento                                         0
# queimada                                              0
# falso_alarme                                          0
# fogacho                                               1
# incendio                                              0
# agricola                                              0
# perimetro                                           NaN
# aps                                                 NaN
# causa                                               NaN
# tipo_causa                                          NaN
# LAT                                           41.390544
# LON                                           -8.006846
# Name: 6, dtype: object
# 2009-07-21_41.39054365_-8.006846020187858.csv 2009-07-21_41.39054365_-8.006846020187858_radiation.csv
# True True
# 220.0
# 17.8
# 2009-07-21T22:00
# ano                                                        2009
# codigo_sgif                                           DM4092248
# tipo                                                  Florestal
# distrito                                                  Braga
# concelho                                             Vila Verde
# freguesia                                               Rio Mau
# local                        L. LAMEIRINHAS (RIO MAU) (RIO MAU)
# ine                                                       31339
# x                                                        168727
# y                                                        525550
# data_alerta                                          2009-09-09
# hora_alerta                                            16:07:00
# data_extincao                                        2009-09-09
# hora_extincao                                          21:55:00
# data_primeira_intervencao                            2009-09-09
# hora_primeira_intervencao                              16:29:00
# fonte_alerta                                          Populares
# nut                                                  PT11020639
# area_povoamento                                             0.5
# area_mato                                                   0.5
# area_agricola                                               0.0
# area_pov_mato                                               1.0
# area_total                                                  1.0
# reacendimento                                                 0
# queimada                                                      0
# falso_alarme                                                  0
# fogacho                                                       0
# incendio                                                      1
# agricola                                                      0
# perimetro                                                   NaN
# aps                                                         NaN
# causa                                                      60.0
# tipo_causa                                         Desconhecida
# LAT                                                   41.701415
# LON                                                   -8.511219
# Name: 7, dtype: object
# 2009-09-09_41.70141495_-8.511219435979115.csv 2009-09-09_41.70141495_-8.511219435979115_radiation.csv
# True True
# 388.0
# 30.7
# 2009-09-09T16:00
# ano                                               2009
# codigo_sgif                                  DM4092249
# tipo                                         Florestal
# distrito                                         Braga
# concelho                                          Fafe
# freguesia                                       Golães
# local                        L.SAMOÇA(GOLÃES) (GOLÃES)
# ine                                              30714
# x                                               194764
# y                                               499613
# data_alerta                                 2009-09-09
# hora_alerta                                   16:35:00
# data_extincao                               2009-09-09
# hora_extincao                                 18:20:00
# data_primeira_intervencao                   2009-09-09
# hora_primeira_intervencao                     16:45:00
# fonte_alerta                                 Populares
# nut                                         PT11030114
# area_povoamento                                    0.1
# area_mato                                          0.0
# area_agricola                                      0.0
# area_pov_mato                                      0.1
# area_total                                         0.1
# reacendimento                                        0
# queimada                                             0
# falso_alarme                                         0
# fogacho                                              1
# incendio                                             0
# agricola                                             0
# perimetro                                          NaN
# aps                                                NaN
# causa                                              NaN
# tipo_causa                                         NaN
# LAT                                          41.465075
# LON                                          -8.196133
# Name: 8, dtype: object
# 2009-09-09_41.4650753_-8.196132750072195.csv 2009-09-09_41.4650753_-8.196132750072195_radiation.csv
# True True
# 339.0
# 31.6
# 2009-09-09T16:00
# ano                                                2009
# codigo_sgif                                   DM4092305
# tipo                                          Florestal
# distrito                                          Braga
# concelho                              Celorico de Basto
# freguesia                                        Arnóia
# local                        CASTELO (ARNOIA) (Castelo)
# ine                                               30502
# x                                                206633
# y                                                488346
# data_alerta                                  2009-09-11
# hora_alerta                                    01:19:00
# data_extincao                                2009-09-11
# hora_extincao                                  02:30:00
# data_primeira_intervencao                    2009-09-11
# hora_primeira_intervencao                      01:35:00
# fonte_alerta                                  Populares
# nut                                          PT11050502
# area_povoamento                                     0.0
# area_mato                                          0.01
# area_agricola                                       0.0
# area_pov_mato                                      0.01
# area_total                                         0.01
# reacendimento                                         0
# queimada                                              0
# falso_alarme                                          0
# fogacho                                               1
# incendio                                              0
# agricola                                              0
# perimetro                                           NaN
# aps                                                 NaN
# causa                                               NaN
# tipo_causa                                          NaN
# LAT                                           41.390544
# LON                                           -8.006846
# Name: 9, dtype: object
# 2009-09-11_41.39054365_-8.006846020187858.csv 2009-09-11_41.39054365_-8.006846020187858_radiation.csv
# True True
# 220.0
# 20.6
# 2009-09-11T01:00
# ano                                2009
# codigo_sgif                   RO2091268
# tipo                          Florestal
# distrito                         Lisboa
# concelho                         Sintra
# freguesia                      Terrugem
# local                          Fervença
# ine                              111113
# x                                 94190
# y                                208915
# data_alerta                  2009-08-25
# hora_alerta                    14:58:00
# data_extincao                2009-08-25
# hora_extincao                  16:42:00
# data_primeira_intervencao    2009-08-25
# hora_primeira_intervencao      15:12:00
# fonte_alerta                        117
# nut                          PT13020613
# area_povoamento                     0.0
# area_mato                          0.02
# area_agricola                       0.0
# area_pov_mato                      0.02
# area_total                         0.02
# reacendimento                         0
# queimada                              0
# falso_alarme                          0
# fogacho                               1
# incendio                              0
# agricola                              0
# perimetro                           NaN
# aps                                 NaN
# causa                               NaN
# tipo_causa                          NaN
# LAT                           38.849444
# LON                           -9.349496
# Name: 10, dtype: object
# 2009-08-25_38.849444_-9.3494961.csv 2009-08-25_38.849444_-9.3494961_radiation.csv
# True True
# 114.0
# 21.7
# 2009-08-25T14:00
# ano                                            2009
# codigo_sgif                                RO309704
# tipo                                      Florestal
# distrito                                    Setúbal
# concelho                                     Almada
# freguesia                                  Caparica
# local                        R. GAIVOTAS (CAPARICA)
# ine                                          150302
# x                                            107217
# y                                            188879
# data_alerta                              2009-08-07
# hora_alerta                                13:06:00
# data_extincao                            2009-08-07
# hora_extincao                              13:45:00
# data_primeira_intervencao                2009-08-07
# hora_primeira_intervencao                  13:19:00
# fonte_alerta                              Populares
# nut                                      PT13030202
# area_povoamento                                 0.0
# area_mato                                     0.001
# area_agricola                                   0.0
# area_pov_mato                                 0.001
# area_total                                    0.001
# reacendimento                                     0
# queimada                                          0
# falso_alarme                                      0
# fogacho                                           1
# incendio                                          0
# agricola                                          0
# perimetro                                       NaN
# aps                                             NaN
# causa                                           NaN
# tipo_causa                                      NaN
# LAT                                        38.67634
# LON                                       -9.211801
# Name: 11, dtype: object
# 2009-08-07_38.6763403_-9.211800839693492.csv 2009-08-07_38.6763403_-9.211800839693492_radiation.csv
# True True
# 3.0
# 23.1
# 2009-08-07T13:00
# ano                                                                       2009
# codigo_sgif                                                          TM1091131
# tipo                                                                 Florestal
# distrito                                                             Vila Real
# concelho                                                                Chaves
# freguesia                                                 São Pedro De Agostém
# local                        QTª DO REBENTÃO-VILA NOVA DE VEIGA (Quinta do ...
# ine                                                                     170333
# x                                                                       244734
# y                                                                       519712
# data_alerta                                                         2009-05-04
# hora_alerta                                                           14:26:00
# data_extincao                                                       2009-05-04
# hora_extincao                                                         17:50:00
# data_primeira_intervencao                                           2009-05-04
# hora_primeira_intervencao                                             14:40:00
# fonte_alerta                                                         Populares
# nut                                                                 PT11080433
# area_povoamento                                                            3.0
# area_mato                                                                  0.0
# area_agricola                                                              0.0
# area_pov_mato                                                              3.0
# area_total                                                                 3.0
# reacendimento                                                                0
# queimada                                                                     0
# falso_alarme                                                                 0
# fogacho                                                                      0
# incendio                                                                     1
# agricola                                                                     0
# perimetro                                                                  NaN
# aps                                                                        NaN
# causa                                                                      NaN
# tipo_causa                                                                 NaN
# LAT                                                                  41.711985
# LON                                                                  -7.492878
# Name: 12, dtype: object
# 2009-05-04_41.7119851_-7.4928779.csv 2009-05-04_41.7119851_-7.4928779_radiation.csv
# True True
# 399.0
# 23.8
# 2009-05-04T14:00
# ano                                2009
# codigo_sgif                     TM10986
# tipo                          Florestal
# distrito                      Vila Real
# concelho                     Montalegre
# freguesia                         Salto
# local                          Cerdeira
# ine                              170626
# x                                228379
# y                                544025
# data_alerta                  2009-02-27
# hora_alerta                    13:20:00
# data_extincao                2009-02-27
# hora_extincao                  15:11:00
# data_primeira_intervencao    2009-02-27
# hora_primeira_intervencao      13:35:00
# fonte_alerta                  Populares
# nut                          PT11080926
# area_povoamento                     0.0
# area_mato                           1.0
# area_agricola                       0.0
# area_pov_mato                       1.0
# area_total                          1.0
# reacendimento                         0
# queimada                              0
# falso_alarme                          0
# fogacho                               0
# incendio                              1
# agricola                              0
# perimetro                           NaN
# aps                                 NaN
# causa                               NaN
# tipo_causa                          NaN
# LAT                           41.639808
# LON                           -7.946059
# Name: 13, dtype: object
# 2009-02-27_41.6398076_-7.9460595.csv 2009-02-27_41.6398076_-7.9460595_radiation.csv
# True True
# 825.0
# 14.6
# 2009-02-27T13:00
