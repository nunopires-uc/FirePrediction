# %%
import pandas as pd
import requests
import ast
import os

# %%
import pandas as pd
_year = 2009
dfMissing = pd.read_csv(f'error_rows{_year}.csv')
print(len(dfMissing))
# Out:
# 13

# %%
print(len([f for f in os.listdir(f'MissingFiles{_year}') if os.path.isfile(os.path.join(f'MissingFiles{_year}', f))]))
# Out:
# 0

# %%
_year = 2006
dfMissing = pd.read_csv(f'error_rows{_year}.csv')
print(len(dfMissing))
for r in range(0, len(dfMissing)):
    row = dfMissing.iloc[r]

    LAT = row['LAT']
    _DATA = row['data_alerta']
    LON = row['LON']

    _fileName_radiation = _DATA + f"_{LAT}_{LON}_radiation"
    _fileName = _DATA + f"_{LAT}_{LON}"


    #RawData/RawDataAnalysis/MissingFiles2012
    url_rad = f"https://archive-api.open-meteo.com/v1/archive?latitude={LAT}&longitude={LON}&start_date={_DATA}&end_date={_DATA}&hourly=shortwave_radiation,direct_radiation,diffuse_radiation,direct_normal_irradiance,global_tilted_irradiance,terrestrial_radiation,shortwave_radiation_instant,direct_radiation_instant,diffuse_radiation_instant,direct_normal_irradiance_instant,global_tilted_irradiance_instant,terrestrial_radiation_instant"
    #url = f"https://archive-api.open-meteo.com/v1/archive?latitude={LAT}&longitude={LON}&start_date={_DATA}&end_date={_DATA}&hourly=temperature_2m,relative_humidity_2m,dew_point_2m,apparent_temperature,precipitation,rain,snowfall,snow_depth,weather_code,pressure_msl,surface_pressure,cloud_cover,cloud_cover_low,cloud_cover_mid,cloud_cover_high,et0_fao_evapotranspiration,vapour_pressure_deficit,wind_speed_10m,wind_speed_100m,wind_direction_10m,wind_direction_100m,wind_gusts_10m,soil_temperature_0_to_7cm,soil_temperature_7_to_28cm,soil_temperature_28_to_100cm,soil_temperature_100_to_255cm,soil_moisture_0_to_7cm,soil_moisture_7_to_28cm,soil_moisture_28_to_100cm,soil_moisture_100_to_255cm,is_day,sunshine_duration,shortwave_radiation_instant,direct_radiation_instant,diffuse_radiation_instant,direct_normal_irradiance_instant,global_tilted_irradiance_instant,terrestrial_radiation_instant&timezone=GMT"
    #response = requests.get(url)
    response_rad = requests.get(url_rad)

    #print(response.status_code)
    print(response_rad.status_code)

    if((response_rad.status_code == 200)):
        #data = response.json()
        data_rad = response_rad.json()

        #df = pd.json_normalize(data)
        #df.to_csv(f"MissingFiles{_year}/{_fileName}.csv", index=False)

        df_rad = pd.json_normalize(data_rad)
        df_rad.to_csv(f"MissingFiles{_year}/{_fileName_radiation}.csv", index=False)
    else:
        print("Error row:", str(r))
# Out:
# 17
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200

# %%
current_dir = os.getcwd()
root_dir = os.path.dirname(os.path.dirname(current_dir))
_RAWFIRESPATH = f"{root_dir}/RawData/Historical_FiresRAW"

_year = 2005
_file = f"{_RAWFIRESPATH}/{_year}/2005-01-01_37.7388357_-8.750062888101874.csv"
df = pd.read_csv(f"{_file}")

column_names = df.columns.tolist()

column_names = df.columns.tolist()

columns_to_remove = [col for col in column_names if 'hourly_units' in col]
columns_to_remove.extend(['latitude', 'longitude', 'generationtime_ms', 'utc_offset_seconds', 'timezone', 'timezone_abbreviation'])

df = df.drop(columns=columns_to_remove)

updated_column_names = df.columns.tolist()

_file_radiation = _file.replace(".csv", "_radiation.csv")
df = pd.read_csv(f"{_file_radiation}")

df = pd.read_csv(f"{_file_radiation}")
column_names = df.columns.tolist()
print(column_names)

column_names = df.columns.tolist()

columns_to_remove = [col for col in column_names if 'hourly_units' in col]
columns_to_remove.extend(['latitude', 'longitude', 'generationtime_ms', 'utc_offset_seconds', 'timezone', 'timezone_abbreviation', 'elevation', 'hourly.time', 'hourly.global_tilted_irradiance_instant', 'hourly.diffuse_radiation_instant', 'hourly.terrestrial_radiation_instant', 'hourly.direct_radiation_instant', 'hourly.shortwave_radiation_instant', 'hourly.direct_normal_irradiance_instant'])

df = df.drop(columns=columns_to_remove)

updated_column_names_radiation = df.columns.tolist()
print(updated_column_names_radiation)

set1 = set(updated_column_names_radiation)
set2 = set(updated_column_names)

common_elements = set1 & set2

print(common_elements)
# Out:
# ['latitude', 'longitude', 'generationtime_ms', 'utc_offset_seconds', 'timezone', 'timezone_abbreviation', 'elevation', 'hourly_units.time', 'hourly_units.shortwave_radiation', 'hourly_units.direct_radiation', 'hourly_units.diffuse_radiation', 'hourly_units.direct_normal_irradiance', 'hourly_units.global_tilted_irradiance', 'hourly_units.terrestrial_radiation', 'hourly_units.shortwave_radiation_instant', 'hourly_units.direct_radiation_instant', 'hourly_units.diffuse_radiation_instant', 'hourly_units.direct_normal_irradiance_instant', 'hourly_units.global_tilted_irradiance_instant', 'hourly_units.terrestrial_radiation_instant', 'hourly.time', 'hourly.shortwave_radiation', 'hourly.direct_radiation', 'hourly.diffuse_radiation', 'hourly.direct_normal_irradiance', 'hourly.global_tilted_irradiance', 'hourly.terrestrial_radiation', 'hourly.shortwave_radiation_instant', 'hourly.direct_radiation_instant', 'hourly.diffuse_radiation_instant', 'hourly.direct_normal_irradiance_instant', 'hourly.global_tilted_irradiance_instant', 'hourly.terrestrial_radiation_instant']
# ['hourly.shortwave_radiation', 'hourly.direct_radiation', 'hourly.diffuse_radiation', 'hourly.direct_normal_irradiance', 'hourly.global_tilted_irradiance', 'hourly.terrestrial_radiation']
# set()

# %%
_year = 2006

df = pd.read_csv("b2006y.csv")

print(df.head())

dfsourcex = pd.read_csv(f'error_rows{_year}.csv')

for r in range(0, len(dfsourcex)):

    row = dfsourcex.iloc[r]


    print(row)

    DISTRICTO = row['distrito']
    CONCELHO = row['concelho']
    FREGUESIA = row['freguesia']
    LOCAL = row['local']
    LAT = row['LAT']
    _DATA = row['data_alerta']
    LON = row['LON']
    CAUSA = row['tipo_causa']
    ANO = row['ano']
    hora = row['hora_alerta']
    HORA = int(str(hora).split(":")[0])

    if pd.isna(LOCAL):
        LOCAL = 'NC'

    if pd.isna(CAUSA):
        CAUSA = 'NC'

    MeteorologyFile = False
    RadiationFile = False


    _fileName = _DATA + f"_{LAT}_{LON}.csv"
    _fileName_radiation = _DATA + f"_{LAT}_{LON}_radiation.csv"

    print(_fileName, _fileName_radiation)

    # MissingFiles{_year}/{_fileName_radiation}.csv
    isExistMeteorology = os.path.isfile(f'MissingFiles{_year}/{_fileName}')
    if(isExistMeteorology):
        MeteorologyFile = True
    else:
        row_df = pd.DataFrame(row).transpose()  # Convert row (Series) to DataFrame
        row_df.to_csv(f'error_rowsX{_year}.csv', mode='a', header=False, index=False)
        
        continue

    isExistRadiation = os.path.isfile(f'MissingFiles{_year}/{_fileName_radiation}')
    if(isExistRadiation):
        RadiationFile = True
    else:
        row_df = pd.DataFrame(row).transpose()  # Convert row (Series) to DataFrame
        row_df.to_csv(f'error_rowsX{_year}.csv', mode='a', header=False, index=False)
        
        continue

    print(isExistMeteorology, RadiationFile)

    if(MeteorologyFile and RadiationFile):
        try:
            dfMet = pd.read_csv(f"MissingFiles{_year}/{_fileName}")
            dfRad = pd.read_csv(f"MissingFiles{_year}/{_fileName_radiation}")
        except Exception as e:
            print(e)
            row_df = pd.DataFrame(row).transpose()  # Convert row (Series) to DataFrame
            row_df.to_csv(f'error_rowsX{_year}.csv', mode='a', header=False, index=False)
            
            continue

        print(dfMet['elevation'].iloc[0])

        list_from_string = ast.literal_eval(dfMet[updated_column_names[2]].iloc[0])[HORA]

        print(list_from_string)

        list_from_string = ast.literal_eval(dfMet[updated_column_names[1]].iloc[0])[HORA]

        print(list_from_string)

        new_data = {
            'year': ANO,
            'date': f"{_DATA}",
            'district': DISTRICTO,
            'municipality': CONCELHO,
            'parish': FREGUESIA,
            'local': LOCAL,
            'latitude': LAT,
            'longitude': LON,
            'cause': CAUSA,
            'elevation': dfMet['elevation'].iloc[0]
        }

        try:
            for i in range(1, len(updated_column_names)):
                new_data[updated_column_names[i]] = ast.literal_eval(dfMet[updated_column_names[i]].iloc[0])[HORA]
        except Exception as e:
            print("->", e)

        try:
            for i in range(0, len(updated_column_names_radiation)):
                new_data[updated_column_names_radiation[i]] = ast.literal_eval(dfRad[updated_column_names_radiation[i]].iloc[0])[HORA]
        except Exception as e:
            print("-x", e)

        new_df = pd.DataFrame(new_data, index=[0])

        new_df.to_csv('b2006y.csv', mode='a', header=False, index=False)
# Out:
# Empty DataFrame
# Columns: [year, date, district, municipality, parish, local, latitude, longitude, cause, elevation, hourly.time, hourly.temperature_2m, hourly.relative_humidity_2m, hourly.dew_point_2m, hourly.apparent_temperature, hourly.precipitation, hourly.rain, hourly.snowfall, hourly.snow_depth, hourly.weather_code, hourly.pressure_msl, hourly.surface_pressure, hourly.cloud_cover, hourly.cloud_cover_low, hourly.cloud_cover_mid, hourly.cloud_cover_high, hourly.et0_fao_evapotranspiration, hourly.vapour_pressure_deficit, hourly.wind_speed_10m, hourly.wind_speed_100m, hourly.wind_direction_10m, hourly.wind_direction_100m, hourly.wind_gusts_10m, hourly.soil_temperature_0_to_7cm, hourly.soil_temperature_7_to_28cm, hourly.soil_temperature_28_to_100cm, hourly.soil_temperature_100_to_255cm, hourly.soil_moisture_0_to_7cm, hourly.soil_moisture_7_to_28cm, hourly.soil_moisture_28_to_100cm, hourly.soil_moisture_100_to_255cm, hourly.is_day, hourly.sunshine_duration, hourly.shortwave_radiation_instant, hourly.direct_radiation_instant, hourly.diffuse_radiation_instant, hourly.direct_normal_irradiance_instant, hourly.global_tilted_irradiance_instant, hourly.terrestrial_radiation_instant, hourly.shortwave_radiation, hourly.direct_radiation, hourly.diffuse_radiation, hourly.direct_normal_irradiance, hourly.global_tilted_irradiance, hourly.terrestrial_radiation]
# Index: []
#
# [0 rows x 55 columns]
# ano                                  2007
# codigo_sgif                     BL1072108
# tipo                            Florestal
# distrito                            Viseu
# concelho                          Tondela
# freguesia                       Caparrosa
# local                           CAPARROSA
# ine                                182104
# x                                  203331
# y                                  406207
# data_alerta                    2007-11-08
# hora_alerta                      11:32:00
# data_extincao                  2007-11-08
# hora_extincao                    14:30:00
# data_primeira_intervencao      2007-11-08
# hora_primeira_intervencao        11:55:00
# fonte_alerta                       Outros
# nut                            PT12051204
# area_povoamento                       0.0
# area_mato                            0.06
# area_agricola                         0.0
# area_pov_mato                        0.06
# area_total                           0.06
# reacendimento                           1
# queimada                                0
# falso_alarme                            0
# fogacho                                 1
# incendio                                0
# agricola                                0
# perimetro                             NaN
# aps                                   NaN
# causa                                 6.0
# tipo_causa                   Desconhecida
# LAT                              40.62223
# LON                             -8.094324
# Name: 0, dtype: object
# 2007-11-08_40.62223025_-8.094324212310221.csv 2007-11-08_40.62223025_-8.094324212310221_radiation.csv
# True True
# 421.0
# 18.4
# 2007-11-08T11:00
# ano                                            2007
# codigo_sgif                                BL107530
# tipo                                      Florestal
# distrito                                      Viseu
# concelho                                      Sátão
# freguesia                    São Miguel de Vila Boa
# local                              QUINTA DA REGADA
# ine                                          181709
# x                                            231496
# y                                            415137
# data_alerta                              2007-08-06
# hora_alerta                                18:09:00
# data_extincao                            2007-08-06
# hora_extincao                              19:20:00
# data_primeira_intervencao                2007-08-06
# hora_primeira_intervencao                  18:17:00
# fonte_alerta                              Populares
# nut                                      PT12051109
# area_povoamento                                 0.0
# area_mato                                     0.005
# area_agricola                                   0.0
# area_pov_mato                                 0.005
# area_total                                    0.005
# reacendimento                                     0
# queimada                                          0
# falso_alarme                                      0
# fogacho                                           1
# incendio                                          0
# agricola                                          0
# perimetro                                       NaN
# aps                                             NaN
# causa                                         610.0
# tipo_causa                             Desconhecida
# LAT                                       40.701846
# LON                                       -7.755847
# Name: 1, dtype: object
# 2007-08-06_40.7018457_-7.7558475.csv 2007-08-06_40.7018457_-7.7558475_radiation.csv
# True True
# 397.0
# 24.8
# 2007-08-06T18:00
# ano                                          2007
# codigo_sgif                             DM2071965
# tipo                                    Florestal
# distrito                                    Porto
# concelho                                 Penafiel
# freguesia                                Valpedre
# local                        LG. XISTO (VALPEDRE)
# ine                                        131136
# x                                          185441
# y                                          463145
# data_alerta                            2007-09-06
# hora_alerta                              05:29:00
# data_extincao                          2007-09-06
# hora_extincao                            11:15:00
# data_primeira_intervencao              2007-09-06
# hora_primeira_intervencao                05:35:00
# fonte_alerta                                  117
# nut                                    PT11051336
# area_povoamento                               0.0
# area_mato                                    0.04
# area_agricola                                 0.0
# area_pov_mato                                0.04
# area_total                                   0.04
# reacendimento                                   0
# queimada                                        0
# falso_alarme                                    0
# fogacho                                         1
# incendio                                        0
# agricola                                        0
# perimetro                                     NaN
# aps                                           NaN
# causa                                         NaN
# tipo_causa                                    NaN
# LAT                                     41.146573
# LON                                     -8.311099
# Name: 2, dtype: object
# 2007-09-06_41.14657255_-8.311098656300938.csv 2007-09-06_41.14657255_-8.311098656300938_radiation.csv
# True True
# 401.0
# 18.1
# 2007-09-06T05:00
# ano                                                2007
# codigo_sgif                                    DM207361
# tipo                                          Florestal
# distrito                                          Porto
# concelho                              Paços de Ferreira
# freguesia                                     Arreigada
# local                        R. DE S. PEDRO (Arreigada)
# ine                                              130901
# x                                                178244
# y                                                475756
# data_alerta                                  2007-01-30
# hora_alerta                                    23:56:00
# data_extincao                                2007-01-31
# hora_extincao                                  01:12:00
# data_primeira_intervencao                    2007-01-31
# hora_primeira_intervencao                      00:01:00
# fonte_alerta                                  Populares
# nut                                          PT11051101
# area_povoamento                                     0.0
# area_mato                                          0.01
# area_agricola                                       0.0
# area_pov_mato                                      0.01
# area_total                                         0.01
# reacendimento                                         0
# queimada                                              0
# falso_alarme                                          0
# fogacho                                               1
# incendio                                              0
# agricola                                              0
# perimetro                                           NaN
# aps                                                 NaN
# causa                                               NaN
# tipo_causa                                          NaN
# LAT                                           41.250502
# LON                                           -8.397302
# Name: 3, dtype: object
# 2007-01-30_41.2505024_-8.397302311430758.csv 2007-01-30_41.2505024_-8.397302311430758_radiation.csv
# True True
# 244.0
# 1.5
# 2007-01-30T23:00
# ano                                                                  2007
# codigo_sgif                                                     DM2074203
# tipo                                                            Florestal
# distrito                                                            Porto
# concelho                                                Vila Nova de Gaia
# freguesia                                                           Grijó
# local                        TV. LAVANDEIRA (Travessa Nova da Lavandeira)
# ine                                                                131706
# x                                                                  163688
# y                                                                  449947
# data_alerta                                                    2007-11-13
# hora_alerta                                                      03:51:00
# data_extincao                                                  2007-11-13
# hora_extincao                                                    05:46:00
# data_primeira_intervencao                                      2007-11-13
# hora_primeira_intervencao                                        04:00:00
# fonte_alerta                                                    Populares
# nut                                                            PT11040906
# area_povoamento                                                       0.0
# area_mato                                                            0.02
# area_agricola                                                         0.0
# area_pov_mato                                                        0.02
# area_total                                                           0.02
# reacendimento                                                           0
# queimada                                                                0
# falso_alarme                                                            0
# fogacho                                                                 1
# incendio                                                                0
# agricola                                                                0
# perimetro                                                             NaN
# aps                                                                   NaN
# causa                                                                 NaN
# tipo_causa                                                            NaN
# LAT                                                             41.030392
# LON                                                             -8.583434
# Name: 4, dtype: object
# 2007-11-13_41.030392250000006_-8.583434430828127.csv 2007-11-13_41.030392250000006_-8.583434430828127_radiation.csv
# True True
# 110.0
# 7.8
# 2007-11-13T03:00
# ano                                       2007
# codigo_sgif                          DM2074216
# tipo                                 Florestal
# distrito                                 Porto
# concelho                     Vila Nova de Gaia
# freguesia                                Grijó
# local                               Murracezes
# ine                                     131706
# x                                       163063
# y                                       451381
# data_alerta                         2007-11-13
# hora_alerta                           13:28:00
# data_extincao                       2007-11-13
# hora_extincao                         16:33:00
# data_primeira_intervencao           2007-11-13
# hora_primeira_intervencao             13:35:00
# fonte_alerta                               117
# nut                                 PT11040906
# area_povoamento                            0.0
# area_mato                                  1.0
# area_agricola                              0.0
# area_pov_mato                              1.0
# area_total                                 1.0
# reacendimento                                0
# queimada                                     0
# falso_alarme                                 0
# fogacho                                      0
# incendio                                     1
# agricola                                     0
# perimetro                                  NaN
# aps                                        NaN
# causa                                      NaN
# tipo_causa                                 NaN
# LAT                                  41.030392
# LON                                  -8.583434
# Name: 5, dtype: object
# 2007-11-13_41.030392250000006_-8.583434430828127.csv 2007-11-13_41.030392250000006_-8.583434430828127_radiation.csv
# True True
# 110.0
# 18.9
# 2007-11-13T13:00
# ano                                                2007
# codigo_sgif                                    DM207449
# tipo                                          Florestal
# distrito                                          Porto
# concelho                                    Santo Tirso
# freguesia                                   Santo Tirso
# local                        VARZAE MONTE (SANTO TIRSO)
# ine                                              131422
# x                                                171365
# y                                                486364
# data_alerta                                  2007-05-16
# hora_alerta                                    21:49:00
# data_extincao                                2007-05-16
# hora_extincao                                  22:30:00
# data_primeira_intervencao                    2007-05-16
# hora_primeira_intervencao                      22:00:00
# fonte_alerta                                  Populares
# nut                                          PT11030422
# area_povoamento                                     0.0
# area_mato                                          0.01
# area_agricola                                       0.0
# area_pov_mato                                      0.01
# area_total                                         0.01
# reacendimento                                         0
# queimada                                              0
# falso_alarme                                          0
# fogacho                                               1
# incendio                                              0
# agricola                                              0
# perimetro                                           NaN
# aps                                                 NaN
# causa                                               NaN
# tipo_causa                                          NaN
# LAT                                            41.35107
# LON                                            -8.47341
# Name: 6, dtype: object
# 2007-05-16_41.35107_-8.4734104.csv 2007-05-16_41.35107_-8.4734104_radiation.csv
# True True
# 35.0
# 19.1
# 2007-05-16T21:00
# ano                                       2007
# codigo_sgif                           DM207596
# tipo                                 Florestal
# distrito                                 Porto
# concelho                     Vila Nova de Gaia
# freguesia                               Olival
# local                                  ARNELAS
# ine                                     131711
# x                                       167297
# y                                       455481
# data_alerta                         2007-06-23
# hora_alerta                           23:10:00
# data_extincao                       2007-06-24
# hora_extincao                         01:21:00
# data_primeira_intervencao           2007-06-23
# hora_primeira_intervencao             23:16:00
# fonte_alerta                               117
# nut                                 PT11040911
# area_povoamento                            0.0
# area_mato                                  0.1
# area_agricola                              0.0
# area_pov_mato                              0.1
# area_total                                 0.1
# reacendimento                                0
# queimada                                     0
# falso_alarme                                 0
# fogacho                                      1
# incendio                                     0
# agricola                                     0
# perimetro                                  NaN
# aps                                        NaN
# causa                                      NaN
# tipo_causa                                 NaN
# LAT                                  41.082713
# LON                                  -8.523532
# Name: 7, dtype: object
# 2007-06-23_41.0827135_-8.5235322.csv 2007-06-23_41.0827135_-8.5235322_radiation.csv
# True True
# 29.0
# 15.5
# 2007-06-23T23:00
# ano                                                                 2007
# codigo_sgif                                                    DM4072198
# tipo                                                           Florestal
# distrito                                                           Braga
# concelho                                             Cabeceiras de Basto
# freguesia                                                      Rio Douro
# local                        MEIJOADELA (RIO DOURO) (Alto da Meijoadela)
# ine                                                                30415
# x                                                                 220705
# y                                                                 510822
# data_alerta                                                   2007-10-29
# hora_alerta                                                     18:50:00
# data_extincao                                                 2007-10-29
# hora_extincao                                                   22:00:00
# data_primeira_intervencao                                     2007-10-29
# hora_primeira_intervencao                                       19:30:00
# fonte_alerta                                                   Populares
# nut                                                           PT11050315
# area_povoamento                                                      0.0
# area_mato                                                            0.0
# area_agricola                                                        0.0
# area_pov_mato                                                        0.0
# area_total                                                           0.0
# reacendimento                                                          0
# queimada                                                               0
# falso_alarme                                                           0
# fogacho                                                                1
# incendio                                                               0
# agricola                                                               0
# perimetro                                              Serra da Cabreira
# aps                                                                  NaN
# causa                                                                NaN
# tipo_causa                                                           NaN
# LAT                                                            41.551208
# LON                                                            -7.967877
# Name: 8, dtype: object
# 2007-10-29_41.551208_-7.9678771.csv 2007-10-29_41.551208_-7.9678771_radiation.csv
# True True
# 403.0
# 14.3
# 2007-10-29T18:00
# ano                                                             2007
# codigo_sgif                                                RO1071361
# tipo                                                       Florestal
# distrito                                                    Santarém
# concelho                                                   Benavente
# freguesia                                                  Benavente
# local                        QUINTA VALE Dª FRANCA (Monte da Quinta)
# ine                                                           140501
# x                                                             148106
# y                                                             221219
# data_alerta                                               2007-11-11
# hora_alerta                                                 16:05:00
# data_extincao                                             2007-11-11
# hora_extincao                                               16:39:00
# data_primeira_intervencao                                 2007-11-11
# hora_primeira_intervencao                                   16:25:00
# fonte_alerta                                                     117
# nut                                                       PT13050401
# area_povoamento                                                  0.0
# area_mato                                                     0.0005
# area_agricola                                                    0.0
# area_pov_mato                                                 0.0005
# area_total                                                    0.0005
# reacendimento                                                      0
# queimada                                                           0
# falso_alarme                                                       0
# fogacho                                                            1
# incendio                                                           0
# agricola                                                           0
# perimetro                                                        NaN
# aps                                                              NaN
# causa                                                            NaN
# tipo_causa                                                       NaN
# LAT                                                        38.958439
# LON                                                        -8.810396
# Name: 9, dtype: object
# 2007-11-11_38.95843905_-8.810396284134132.csv 2007-11-11_38.95843905_-8.810396284134132_radiation.csv
# True True
# 15.0
# 23.0
# 2007-11-11T16:00
# ano                                  2007
# codigo_sgif                      RO107517
# tipo                            Florestal
# distrito                         Santarém
# concelho                            Ourém
# freguesia                          Fátima
# local                        Cova da Iria
# ine                                142106
# x                                  154055
# y                                  296155
# data_alerta                    2007-07-28
# hora_alerta                      18:20:00
# data_extincao                  2007-07-28
# hora_extincao                    19:31:00
# data_primeira_intervencao      2007-07-28
# hora_primeira_intervencao        18:21:00
# fonte_alerta                    Populares
# nut                            PT13041106
# area_povoamento                       0.0
# area_mato                           0.004
# area_agricola                         0.0
# area_pov_mato                       0.004
# area_total                          0.004
# reacendimento                           0
# queimada                                0
# falso_alarme                            0
# fogacho                                 1
# incendio                                0
# agricola                                0
# perimetro                             NaN
# aps                                   NaN
# causa                                 6.0
# tipo_causa                   Desconhecida
# LAT                             39.634964
# LON                              -8.68267
# Name: 10, dtype: object
# 2007-07-28_39.6349644_-8.68267.csv 2007-07-28_39.6349644_-8.68267_radiation.csv
# True True
# 345.0
# 28.7
# 2007-07-28T18:00
# ano                                                              2007
# codigo_sgif                                                  RO207571
# tipo                                                        Florestal
# distrito                                                       Lisboa
# concelho                                                      Amadora
# freguesia                                                        Mina
# local                        CASAL DAS BRANCAS (Casal da Fonte Santa)
# ine                                                            111506
# x                                                              104029
# y                                                              203333
# data_alerta                                                2007-07-13
# hora_alerta                                                  14:24:00
# data_extincao                                              2007-07-13
# hora_extincao                                                16:08:00
# data_primeira_intervencao                                         NaN
# hora_primeira_intervencao                                         NaN
# fonte_alerta                                                Populares
# nut                                                        PT13020106
# area_povoamento                                                   0.0
# area_mato                                                         1.5
# area_agricola                                                     0.0
# area_pov_mato                                                     1.5
# area_total                                                        1.5
# reacendimento                                                       0
# queimada                                                            0
# falso_alarme                                                        0
# fogacho                                                             0
# incendio                                                            1
# agricola                                                            0
# perimetro                                                         NaN
# aps                                                               NaN
# causa                                                             NaN
# tipo_causa                                                        NaN
# LAT                                                         38.759722
# LON                                                         -9.235813
# Name: 11, dtype: object
# 2007-07-13_38.7597223_-9.2358134.csv 2007-07-13_38.7597223_-9.2358134_radiation.csv
# True True
# 130.0
# 26.3
# 2007-07-13T14:00
