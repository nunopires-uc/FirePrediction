# %%
import pandas as pd
import requests
import ast
import os
# Out:
# /tmp/ipykernel_15615/1817075740.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
import pandas as pd
_year = 2009
dfMissing = pd.read_csv(f'error_rows{_year}.csv')
print(len(dfMissing))
# Out:
# 13

# %%
print(len([f for f in os.listdir(f'MissingFiles{_year}') if os.path.isfile(os.path.join(f'MissingFiles{_year}', f))]))
# Out:
# 0

# %%
_year = 2005
dfMissing = pd.read_csv(f'error_rows{_year}.csv')
print(len(dfMissing))
for r in range(0, len(dfMissing)):
    row = dfMissing.iloc[r]

    LAT = row['LAT']
    _DATA = row['data_alerta']
    LON = row['LON']

    _fileName_radiation = _DATA + f"_{LAT}_{LON}_radiation"
    _fileName = _DATA + f"_{LAT}_{LON}"


    #RawData/RawDataAnalysis/MissingFiles2012
    #url_rad = f"https://archive-api.open-meteo.com/v1/archive?latitude={LAT}&longitude={LON}&start_date={_DATA}&end_date={_DATA}&hourly=shortwave_radiation,direct_radiation,diffuse_radiation,direct_normal_irradiance,global_tilted_irradiance,terrestrial_radiation,shortwave_radiation_instant,direct_radiation_instant,diffuse_radiation_instant,direct_normal_irradiance_instant,global_tilted_irradiance_instant,terrestrial_radiation_instant"
    url = f"https://archive-api.open-meteo.com/v1/archive?latitude={LAT}&longitude={LON}&start_date={_DATA}&end_date={_DATA}&hourly=temperature_2m,relative_humidity_2m,dew_point_2m,apparent_temperature,precipitation,rain,snowfall,snow_depth,weather_code,pressure_msl,surface_pressure,cloud_cover,cloud_cover_low,cloud_cover_mid,cloud_cover_high,et0_fao_evapotranspiration,vapour_pressure_deficit,wind_speed_10m,wind_speed_100m,wind_direction_10m,wind_direction_100m,wind_gusts_10m,soil_temperature_0_to_7cm,soil_temperature_7_to_28cm,soil_temperature_28_to_100cm,soil_temperature_100_to_255cm,soil_moisture_0_to_7cm,soil_moisture_7_to_28cm,soil_moisture_28_to_100cm,soil_moisture_100_to_255cm,is_day,sunshine_duration,shortwave_radiation_instant,direct_radiation_instant,diffuse_radiation_instant,direct_normal_irradiance_instant,global_tilted_irradiance_instant,terrestrial_radiation_instant&timezone=GMT"
    response = requests.get(url)
    #response_rad = requests.get(url_rad)

    print(response.status_code)
    #print(response_rad.status_code)

    if((response.status_code == 200)):
        data = response.json()
        #data_rad = response_rad.json()

        df = pd.json_normalize(data)
        df.to_csv(f"MissingFiles{_year}/{_fileName}.csv", index=False)

        #df_rad = pd.json_normalize(data_rad)
        #df_rad.to_csv(f"MissingFiles{_year}/{_fileName_radiation}.csv", index=False)
    else:
        print("Error row:", str(r))
# Out:
# 17
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200

# %%
current_dir = os.getcwd()
root_dir = os.path.dirname(os.path.dirname(current_dir))
_RAWFIRESPATH = f"{root_dir}/RawData/Historical_FiresRAW"

_year = 2005
_file = f"{_RAWFIRESPATH}/{_year}/2005-01-01_37.7388357_-8.750062888101874.csv"
df = pd.read_csv(f"{_file}")

column_names = df.columns.tolist()

column_names = df.columns.tolist()

columns_to_remove = [col for col in column_names if 'hourly_units' in col]
columns_to_remove.extend(['latitude', 'longitude', 'generationtime_ms', 'utc_offset_seconds', 'timezone', 'timezone_abbreviation'])

df = df.drop(columns=columns_to_remove)

updated_column_names = df.columns.tolist()

_file_radiation = _file.replace(".csv", "_radiation.csv")
df = pd.read_csv(f"{_file_radiation}")

df = pd.read_csv(f"{_file_radiation}")
column_names = df.columns.tolist()
print(column_names)

column_names = df.columns.tolist()

columns_to_remove = [col for col in column_names if 'hourly_units' in col]
columns_to_remove.extend(['latitude', 'longitude', 'generationtime_ms', 'utc_offset_seconds', 'timezone', 'timezone_abbreviation', 'elevation', 'hourly.time', 'hourly.global_tilted_irradiance_instant', 'hourly.diffuse_radiation_instant', 'hourly.terrestrial_radiation_instant', 'hourly.direct_radiation_instant', 'hourly.shortwave_radiation_instant', 'hourly.direct_normal_irradiance_instant'])

df = df.drop(columns=columns_to_remove)

updated_column_names_radiation = df.columns.tolist()
print(updated_column_names_radiation)

set1 = set(updated_column_names_radiation)
set2 = set(updated_column_names)

common_elements = set1 & set2

print(common_elements)
# Out:
# ['latitude', 'longitude', 'generationtime_ms', 'utc_offset_seconds', 'timezone', 'timezone_abbreviation', 'elevation', 'hourly_units.time', 'hourly_units.shortwave_radiation', 'hourly_units.direct_radiation', 'hourly_units.diffuse_radiation', 'hourly_units.direct_normal_irradiance', 'hourly_units.global_tilted_irradiance', 'hourly_units.terrestrial_radiation', 'hourly_units.shortwave_radiation_instant', 'hourly_units.direct_radiation_instant', 'hourly_units.diffuse_radiation_instant', 'hourly_units.direct_normal_irradiance_instant', 'hourly_units.global_tilted_irradiance_instant', 'hourly_units.terrestrial_radiation_instant', 'hourly.time', 'hourly.shortwave_radiation', 'hourly.direct_radiation', 'hourly.diffuse_radiation', 'hourly.direct_normal_irradiance', 'hourly.global_tilted_irradiance', 'hourly.terrestrial_radiation', 'hourly.shortwave_radiation_instant', 'hourly.direct_radiation_instant', 'hourly.diffuse_radiation_instant', 'hourly.direct_normal_irradiance_instant', 'hourly.global_tilted_irradiance_instant', 'hourly.terrestrial_radiation_instant']
# ['hourly.shortwave_radiation', 'hourly.direct_radiation', 'hourly.diffuse_radiation', 'hourly.direct_normal_irradiance', 'hourly.global_tilted_irradiance', 'hourly.terrestrial_radiation']
# set()

# %%
_year = 2005

df = pd.read_csv("b2005y.csv")

print(df.head())

dfsourcex = pd.read_csv(f'error_rows{_year}.csv')

for r in range(0, len(dfsourcex)):

    row = dfsourcex.iloc[r]


    print(row)

    DISTRICTO = row['distrito']
    CONCELHO = row['concelho']
    FREGUESIA = row['freguesia']
    LOCAL = row['local']
    LAT = row['LAT']
    _DATA = row['data_alerta']
    LON = row['LON']
    CAUSA = row['tipo_causa']
    ANO = row['ano']
    hora = row['hora_alerta']
    HORA = int(str(hora).split(":")[0])

    if pd.isna(LOCAL):
        LOCAL = 'NC'

    if pd.isna(CAUSA):
        CAUSA = 'NC'

    MeteorologyFile = False
    RadiationFile = False


    _fileName = _DATA + f"_{LAT}_{LON}.csv"
    _fileName_radiation = _DATA + f"_{LAT}_{LON}_radiation.csv"

    print(_fileName, _fileName_radiation)

    # MissingFiles{_year}/{_fileName_radiation}.csv
    isExistMeteorology = os.path.isfile(f'MissingFiles{_year}/{_fileName}')
    if(isExistMeteorology):
        MeteorologyFile = True
    else:
        row_df = pd.DataFrame(row).transpose()  # Convert row (Series) to DataFrame
        row_df.to_csv(f'error_rowsX{_year}.csv', mode='a', header=False, index=False)
        
        continue

    isExistRadiation = os.path.isfile(f'MissingFiles{_year}/{_fileName_radiation}')
    if(isExistRadiation):
        RadiationFile = True
    else:
        row_df = pd.DataFrame(row).transpose()  # Convert row (Series) to DataFrame
        row_df.to_csv(f'error_rowsX{_year}.csv', mode='a', header=False, index=False)
        
        continue

    print(isExistMeteorology, RadiationFile)

    if(MeteorologyFile and RadiationFile):
        try:
            dfMet = pd.read_csv(f"MissingFiles{_year}/{_fileName}")
            dfRad = pd.read_csv(f"MissingFiles{_year}/{_fileName_radiation}")
        except Exception as e:
            print(e)
            row_df = pd.DataFrame(row).transpose()  # Convert row (Series) to DataFrame
            row_df.to_csv(f'error_rowsX{_year}.csv', mode='a', header=False, index=False)
            
            continue

        print(dfMet['elevation'].iloc[0])

        list_from_string = ast.literal_eval(dfMet[updated_column_names[2]].iloc[0])[HORA]

        print(list_from_string)

        list_from_string = ast.literal_eval(dfMet[updated_column_names[1]].iloc[0])[HORA]

        print(list_from_string)

        new_data = {
            'year': ANO,
            'date': f"{_DATA}",
            'district': DISTRICTO,
            'municipality': CONCELHO,
            'parish': FREGUESIA,
            'local': LOCAL,
            'latitude': LAT,
            'longitude': LON,
            'cause': CAUSA,
            'elevation': dfMet['elevation'].iloc[0]
        }

        try:
            for i in range(1, len(updated_column_names)):
                new_data[updated_column_names[i]] = ast.literal_eval(dfMet[updated_column_names[i]].iloc[0])[HORA]
        except Exception as e:
            print("->", e)

        try:
            for i in range(0, len(updated_column_names_radiation)):
                new_data[updated_column_names_radiation[i]] = ast.literal_eval(dfRad[updated_column_names_radiation[i]].iloc[0])[HORA]
        except Exception as e:
            print("-x", e)

        new_df = pd.DataFrame(new_data, index=[0])

        new_df.to_csv('b2005y.csv', mode='a', header=False, index=False)
# Out:
# Empty DataFrame
# Columns: [year, date, district, municipality, parish, local, latitude, longitude, cause, elevation, hourly.time, hourly.temperature_2m, hourly.relative_humidity_2m, hourly.dew_point_2m, hourly.apparent_temperature, hourly.precipitation, hourly.rain, hourly.snowfall, hourly.snow_depth, hourly.weather_code, hourly.pressure_msl, hourly.surface_pressure, hourly.cloud_cover, hourly.cloud_cover_low, hourly.cloud_cover_mid, hourly.cloud_cover_high, hourly.et0_fao_evapotranspiration, hourly.vapour_pressure_deficit, hourly.wind_speed_10m, hourly.wind_speed_100m, hourly.wind_direction_10m, hourly.wind_direction_100m, hourly.wind_gusts_10m, hourly.soil_temperature_0_to_7cm, hourly.soil_temperature_7_to_28cm, hourly.soil_temperature_28_to_100cm, hourly.soil_temperature_100_to_255cm, hourly.soil_moisture_0_to_7cm, hourly.soil_moisture_7_to_28cm, hourly.soil_moisture_28_to_100cm, hourly.soil_moisture_100_to_255cm, hourly.is_day, hourly.sunshine_duration, hourly.shortwave_radiation_instant, hourly.direct_radiation_instant, hourly.diffuse_radiation_instant, hourly.direct_normal_irradiance_instant, hourly.global_tilted_irradiance_instant, hourly.terrestrial_radiation_instant, hourly.shortwave_radiation, hourly.direct_radiation, hourly.diffuse_radiation, hourly.direct_normal_irradiance, hourly.global_tilted_irradiance, hourly.terrestrial_radiation]
# Index: []
#
# [0 rows x 55 columns]
# ano                                    2006
# codigo_sgif                        BI206340
# tipo                              Florestal
# distrito                     Castelo Branco
# concelho                          Penamacor
# freguesia                            Meimoa
# local                                MEIMOA
# ine                                   50708
# x                                    280712
# y                                    362554
# data_alerta                      2006-07-08
# hora_alerta                        14:33:00
# data_extincao                    2006-07-08
# hora_extincao                      22:05:00
# data_primeira_intervencao        2006-07-08
# hora_primeira_intervencao          14:47:00
# fonte_alerta                             PV
# nut                              PT12090308
# area_povoamento                         0.0
# area_mato                               1.0
# area_agricola                           0.0
# area_pov_mato                           1.0
# area_total                              1.0
# reacendimento                             0
# queimada                                  0
# falso_alarme                              0
# fogacho                                   0
# incendio                                  1
# agricola                                  0
# perimetro                               NaN
# aps                                     NaN
# causa                                   NaN
# tipo_causa                              NaN
# LAT                               40.248755
# LON                                -7.16738
# Name: 0, dtype: object
# 2006-07-08_40.2487553_-7.1673801.csv 2006-07-08_40.2487553_-7.1673801_radiation.csv
# True True
# 504.0
# 34.5
# 2006-07-08T14:00
# ano                                     2006
# codigo_sgif                         BL106656
# tipo                               Florestal
# distrito                               Viseu
# concelho                             Cinfães
# freguesia                            Cinfães
# local                        CADIS (CINFÃES)
# ine                                   180403
# x                                     203581
# y                                     455876
# data_alerta                       2006-06-05
# hora_alerta                         21:14:00
# data_extincao                     2006-06-05
# hora_extincao                       22:46:00
# data_primeira_intervencao         2006-06-05
# hora_primeira_intervencao           21:30:00
# fonte_alerta                       Populares
# nut                               PT11050603
# area_povoamento                          0.0
# area_mato                               0.18
# area_agricola                            0.0
# area_pov_mato                           0.18
# area_total                              0.18
# reacendimento                              0
# queimada                                   0
# falso_alarme                               0
# fogacho                                    1
# incendio                                   0
# agricola                                   0
# perimetro                                NaN
# aps                                      NaN
# causa                                    NaN
# tipo_causa                               NaN
# LAT                                41.072165
# LON                                -8.089473
# Name: 1, dtype: object
# 2006-06-05_41.0721651_-8.0894728.csv 2006-06-05_41.0721651_-8.0894728_radiation.csv
# True True
# 400.0
# 24.8
# 2006-06-05T21:00
# ano                                  2006
# codigo_sgif                      BL106610
# tipo                            Florestal
# distrito                            Viseu
# concelho                            Sátão
# freguesia                      Vila Longa
# local                          VILA LONGA
# ine                                181712
# x                                  245756
# y                                  419897
# data_alerta                    2006-06-03
# hora_alerta                      11:30:00
# data_extincao                  2006-06-03
# hora_extincao                    13:15:00
# data_primeira_intervencao      2006-06-03
# hora_primeira_intervencao        11:45:00
# fonte_alerta                    Populares
# nut                            PT12051112
# area_povoamento                       0.0
# area_mato                           0.001
# area_agricola                         0.0
# area_pov_mato                       0.001
# area_total                          0.001
# reacendimento                           0
# queimada                                0
# falso_alarme                            0
# fogacho                                 1
# incendio                                0
# agricola                                0
# perimetro                             NaN
# aps                                   NaN
# causa                               630.0
# tipo_causa                   Desconhecida
# LAT                              40.74281
# LON                             -7.588323
# Name: 2, dtype: object
# 2006-06-03_40.7428102_-7.588322820309436.csv 2006-06-03_40.7428102_-7.588322820309436_radiation.csv
# True True
# 588.0
# 22.0
# 2006-06-03T11:00
# ano                                    2006
# codigo_sgif                       BL3061741
# tipo                              Florestal
# distrito                             Aveiro
# concelho                             Águeda
# freguesia                    Lamas do Vouga
# local                              Pedaçães
# ine                                   10110
# x                                    171329
# y                                    406555
# data_alerta                      2006-08-06
# hora_alerta                        01:10:00
# data_extincao                    2006-08-06
# hora_extincao                      03:00:00
# data_primeira_intervencao               NaN
# hora_primeira_intervencao               NaN
# fonte_alerta                      Populares
# nut                              PT12010110
# area_povoamento                         0.5
# area_mato                               0.0
# area_agricola                           0.0
# area_pov_mato                           0.5
# area_total                              0.5
# reacendimento                             0
# queimada                                  0
# falso_alarme                              0
# fogacho                                   1
# incendio                                  0
# agricola                                  0
# perimetro                               NaN
# aps                                     NaN
# causa                                   6.0
# tipo_causa                     Desconhecida
# LAT                               40.594189
# LON                               -8.459642
# Name: 3, dtype: object
# 2006-08-06_40.5941892_-8.4596416.csv 2006-08-06_40.5941892_-8.4596416_radiation.csv
# True True
# 84.0
# 23.1
# 2006-08-06T01:00
# ano                                                2006
# codigo_sgif                                   BL4061281
# tipo                                          Florestal
# distrito                                         Leiria
# concelho                                         Leiria
# freguesia                                        Cortes
# local                        CURVA DA BOIÇA (CURVACHIA)
# ine                                              100911
# x                                                146342
# y                                                304662
# data_alerta                                  2006-08-15
# hora_alerta                                    15:19:00
# data_extincao                                2006-08-16
# hora_extincao                                  08:15:00
# data_primeira_intervencao                           NaN
# hora_primeira_intervencao                           NaN
# fonte_alerta                                  Populares
# nut                                          PT12030211
# area_povoamento                                    3.34
# area_mato                                           0.0
# area_agricola                                       0.0
# area_pov_mato                                      3.34
# area_total                                         3.34
# reacendimento                                         0
# queimada                                              0
# falso_alarme                                          0
# fogacho                                               0
# incendio                                              1
# agricola                                              0
# perimetro                                           NaN
# aps                                                 NaN
# causa                                             610.0
# tipo_causa                                 Desconhecida
# LAT                                           39.701242
# LON                                           -8.785032
# Name: 4, dtype: object
# 2006-08-15_39.7012422_-8.7850315.csv 2006-08-15_39.7012422_-8.7850315_radiation.csv
# True True
# 83.0
# 21.3
# 2006-08-15T15:00
# ano                                            2006
# codigo_sgif                               DM2062370
# tipo                                      Florestal
# distrito                                      Porto
# concelho                                   Penafiel
# freguesia                                 Vila Cova
# local                        CORCOMELOS (Corcovido)
# ine                                          131137
# x                                            190486
# y                                            467003
# data_alerta                              2006-07-11
# hora_alerta                                01:10:00
# data_extincao                            2006-07-11
# hora_extincao                              05:30:00
# data_primeira_intervencao                2006-07-11
# hora_primeira_intervencao                  01:20:00
# fonte_alerta                                    117
# nut                                      PT11051337
# area_povoamento                                 0.0
# area_mato                                       2.5
# area_agricola                                   0.0
# area_pov_mato                                   2.5
# area_total                                      2.5
# reacendimento                                     0
# queimada                                          0
# falso_alarme                                      0
# fogacho                                           0
# incendio                                          1
# agricola                                          0
# perimetro                                       NaN
# aps                                             NaN
# causa                                           NaN
# tipo_causa                                      NaN
# LAT                                       41.174638
# LON                                        -8.24058
# Name: 5, dtype: object
# 2006-07-11_41.1746375_-8.2405804.csv 2006-07-11_41.1746375_-8.2405804_radiation.csv
# True True
# 311.0
# 21.0
# 2006-07-11T01:00
# ano                                                     2006
# codigo_sgif                                        DM2063889
# tipo                                               Florestal
# distrito                                               Porto
# concelho                                   Paços de Ferreira
# freguesia                                          Freamunde
# local                        RUA DA DEVESA (Rua do Comércio)
# ine                                                   130908
# x                                                     182186
# y                                                     479668
# data_alerta                                       2006-08-07
# hora_alerta                                         07:22:00
# data_extincao                                     2006-08-07
# hora_extincao                                       09:30:00
# data_primeira_intervencao                         2006-08-07
# hora_primeira_intervencao                           07:21:00
# fonte_alerta                                             117
# nut                                               PT11051108
# area_povoamento                                          0.1
# area_mato                                                0.0
# area_agricola                                            0.0
# area_pov_mato                                            0.1
# area_total                                               0.1
# reacendimento                                              0
# queimada                                                   0
# falso_alarme                                               0
# fogacho                                                    1
# incendio                                                   0
# agricola                                                   0
# perimetro                                                NaN
# aps                                                      NaN
# causa                                                    NaN
# tipo_causa                                               NaN
# LAT                                                41.287121
# LON                                                -8.341737
# Name: 6, dtype: object
# 2006-08-07_41.2871214_-8.341737478649442.csv 2006-08-07_41.2871214_-8.341737478649442_radiation.csv
# True True
# 365.0
# 20.7
# 2006-08-07T07:00
# ano                                                    2006
# codigo_sgif                                       DM2063896
# tipo                                              Florestal
# distrito                                              Porto
# concelho                                  Paços de Ferreira
# freguesia                                         Freamunde
# local                        RUA DO MARCO (Rua do Comércio)
# ine                                                  130908
# x                                                    182186
# y                                                    479668
# data_alerta                                      2006-08-07
# hora_alerta                                        09:38:00
# data_extincao                                    2006-08-07
# hora_extincao                                      10:09:00
# data_primeira_intervencao                        2006-08-07
# hora_primeira_intervencao                          09:45:00
# fonte_alerta                                      Populares
# nut                                              PT11051108
# area_povoamento                                         0.0
# area_mato                                              0.01
# area_agricola                                           0.0
# area_pov_mato                                          0.01
# area_total                                             0.01
# reacendimento                                             0
# queimada                                                  0
# falso_alarme                                              0
# fogacho                                                   1
# incendio                                                  0
# agricola                                                  0
# perimetro                                               NaN
# aps                                                     NaN
# causa                                                   NaN
# tipo_causa                                              NaN
# LAT                                               41.287121
# LON                                               -8.341737
# Name: 7, dtype: object
# 2006-08-07_41.2871214_-8.341737478649442.csv 2006-08-07_41.2871214_-8.341737478649442_radiation.csv
# True True
# 365.0
# 23.8
# 2006-08-07T09:00
# ano                                                     2006
# codigo_sgif                                        DM2063902
# tipo                                               Florestal
# distrito                                               Porto
# concelho                                   Paços de Ferreira
# freguesia                                          Freamunde
# local                        RUA DA DEVESA (Rua do Comércio)
# ine                                                   130908
# x                                                     182186
# y                                                     479668
# data_alerta                                       2006-08-07
# hora_alerta                                         10:38:00
# data_extincao                                     2006-08-07
# hora_extincao                                       11:25:00
# data_primeira_intervencao                         2006-08-07
# hora_primeira_intervencao                           10:45:00
# fonte_alerta                                       Populares
# nut                                               PT11051108
# area_povoamento                                          0.0
# area_mato                                               0.01
# area_agricola                                            0.0
# area_pov_mato                                           0.01
# area_total                                              0.01
# reacendimento                                              0
# queimada                                                   0
# falso_alarme                                               0
# fogacho                                                    1
# incendio                                                   0
# agricola                                                   0
# perimetro                                                NaN
# aps                                                      NaN
# causa                                                    NaN
# tipo_causa                                               NaN
# LAT                                                41.287121
# LON                                                -8.341737
# Name: 8, dtype: object
# 2006-08-07_41.2871214_-8.341737478649442.csv 2006-08-07_41.2871214_-8.341737478649442_radiation.csv
# True True
# 365.0
# 25.7
# 2006-08-07T10:00
# ano                                        2006
# codigo_sgif                           DM2065493
# tipo                                  Florestal
# distrito                                  Porto
# concelho                                Paredes
# freguesia                                 Beire
# local                        L. TIJORES (BEIRE)
# ine                                      131004
# x                                        184285
# y                                        475458
# data_alerta                          2006-09-02
# hora_alerta                            05:14:00
# data_extincao                        2006-09-02
# hora_extincao                          06:19:00
# data_primeira_intervencao            2006-09-02
# hora_primeira_intervencao              05:22:00
# fonte_alerta                                117
# nut                                  PT11051204
# area_povoamento                             0.0
# area_mato                                  0.13
# area_agricola                               0.0
# area_pov_mato                              0.13
# area_total                                 0.13
# reacendimento                                 0
# queimada                                      0
# falso_alarme                                  0
# fogacho                                       1
# incendio                                      0
# agricola                                      0
# perimetro                                   NaN
# aps                                         NaN
# causa                                       NaN
# tipo_causa                                  NaN
# LAT                                   41.248189
# LON                                   -8.322918
# Name: 9, dtype: object
# 2006-09-02_41.2481887_-8.322918173550978.csv 2006-09-02_41.2481887_-8.322918173550978_radiation.csv
# True True
# 217.0
# 17.4
# 2006-09-02T05:00
# ano                                      2006
# codigo_sgif                         DM3061570
# tipo                                Florestal
# distrito                     Viana do Castelo
# concelho                        Ponte de Lima
# freguesia                            Gemieira
# local                                 Cancela
# ine                                    160727
# x                                      166913
# y                                      534355
# data_alerta                        2006-09-13
# hora_alerta                          02:50:00
# data_extincao                      2006-09-13
# hora_extincao                        03:55:00
# data_primeira_intervencao          2006-09-13
# hora_primeira_intervencao            02:56:00
# fonte_alerta                        Populares
# nut                                PT11010727
# area_povoamento                           0.0
# area_mato                                0.04
# area_agricola                             0.0
# area_pov_mato                            0.04
# area_total                               0.04
# reacendimento                               0
# queimada                                    0
# falso_alarme                                0
# fogacho                                     1
# incendio                                    0
# agricola                                    0
# perimetro                                 NaN
# aps                                       NaN
# causa                                     NaN
# tipo_causa                                NaN
# LAT                                 41.779383
# LON                                 -8.520385
# Name: 10, dtype: object
# 2006-09-13_41.7793831_-8.5203845.csv 2006-09-13_41.7793831_-8.5203845_radiation.csv
# True True
# 36.0
# 15.7
# 2006-09-13T02:00
# ano                                     2006
# codigo_sgif                        DM4063423
# tipo                               Florestal
# distrito                               Braga
# concelho                     Terras de Bouro
# freguesia                              Souto
# local                              Carvalhal
# ine                                    31014
# x                                     182079
# y                                     525011
# data_alerta                       2006-09-04
# hora_alerta                         05:39:00
# data_extincao                     2006-09-04
# hora_extincao                       08:40:00
# data_primeira_intervencao         2006-09-04
# hora_primeira_intervencao           06:00:00
# fonte_alerta                             117
# nut                               PT11020514
# area_povoamento                          0.0
# area_mato                               0.05
# area_agricola                            0.0
# area_pov_mato                           0.05
# area_total                              0.05
# reacendimento                              0
# queimada                                   0
# falso_alarme                               0
# fogacho                                    1
# incendio                                   0
# agricola                                   0
# perimetro                                NaN
# aps                                      NaN
# causa                                    NaN
# tipo_causa                               NaN
# LAT                                41.693953
# LON                                -8.342989
# Name: 11, dtype: object
# 2006-09-04_41.6939526_-8.3429892.csv 2006-09-04_41.6939526_-8.3429892_radiation.csv
# True True
# 160.0
# 17.0
# 2006-09-04T05:00
# ano                                                      2006
# codigo_sgif                                          RO106458
# tipo                                                Florestal
# distrito                                             Santarém
# concelho                                                Ourém
# freguesia                                               Seiça
# local                        FONTAINHAS DA SERRA (Fontainhas)
# ine                                                    142113
# x                                                      167407
# y                                                      299733
# data_alerta                                        2006-06-09
# hora_alerta                                          01:05:00
# data_extincao                                      2006-06-09
# hora_extincao                                        01:42:00
# data_primeira_intervencao                                 NaN
# hora_primeira_intervencao                                 NaN
# fonte_alerta                                        Populares
# nut                                                PT13041113
# area_povoamento                                           0.0
# area_mato                                               0.001
# area_agricola                                             0.0
# area_pov_mato                                           0.001
# area_total                                              0.001
# reacendimento                                               0
# queimada                                                    0
# falso_alarme                                                0
# fogacho                                                     1
# incendio                                                    0
# agricola                                                    0
# perimetro                                                 NaN
# aps                                                       NaN
# causa                                                     NaN
# tipo_causa                                                NaN
# LAT                                                 39.668867
# LON                                                 -8.517731
# Name: 12, dtype: object
# 2006-06-09_39.6688673_-8.5177306.csv 2006-06-09_39.6688673_-8.5177306_radiation.csv
# True True
# 134.0
# 17.1
# 2006-06-09T01:00
# ano                                        2006
# codigo_sgif                           RO3061841
# tipo                                  Florestal
# distrito                                Setúbal
# concelho                               Sesimbra
# freguesia                    Sesimbra (castelo)
# local                               MAÇA (Maçã)
# ine                                      151101
# x                                        117690
# y                                        167851
# data_alerta                          2006-09-19
# hora_alerta                            13:19:00
# data_extincao                        2006-09-19
# hora_extincao                          14:03:00
# data_primeira_intervencao            2006-09-19
# hora_primeira_intervencao              13:17:00
# fonte_alerta                          Populares
# nut                                  PT13030801
# area_povoamento                             0.0
# area_mato                                 0.001
# area_agricola                               0.0
# area_pov_mato                             0.001
# area_total                                0.001
# reacendimento                                 0
# queimada                                      0
# falso_alarme                                  0
# fogacho                                       1
# incendio                                      0
# agricola                                      0
# perimetro                                   NaN
# aps                                    ARRÁBIDA
# causa                                       NaN
# tipo_causa                                  NaN
# LAT                                   38.477514
# LON                                   -9.073634
# Name: 13, dtype: object
# 2006-09-19_38.4775139_-9.0736338.csv 2006-09-19_38.4775139_-9.0736338_radiation.csv
# True True
# 109.0
# 23.2
# 2006-09-19T13:00
# ano                                                        2006
# codigo_sgif                                            TM106514
# tipo                                                  Florestal
# distrito                                              Vila Real
# concelho                                                 Chaves
# freguesia                                              Sanjurge
# local                        Pereiro de Selão (Alto do Pereiro)
# ine                                                      170328
# x                                                        253616
# y                                                        532885
# data_alerta                                          2006-06-20
# hora_alerta                                            23:02:00
# data_extincao                                        2006-06-21
# hora_extincao                                          02:00:00
# data_primeira_intervencao                            2006-06-20
# hora_primeira_intervencao                              23:25:00
# fonte_alerta                                          Populares
# nut                                                  PT11080428
# area_povoamento                                             0.0
# area_mato                                                   1.0
# area_agricola                                               0.0
# area_pov_mato                                               1.0
# area_total                                                  1.0
# reacendimento                                                 0
# queimada                                                      0
# falso_alarme                                                  0
# fogacho                                                       0
# incendio                                                      1
# agricola                                                      0
# perimetro                                                   NaN
# aps                                                         NaN
# causa                                                       NaN
# tipo_causa                                                  NaN
# LAT                                                   41.776212
# LON                                                   -7.504013
# Name: 14, dtype: object
# 2006-06-20_41.7762124_-7.5040129.csv 2006-06-20_41.7762124_-7.5040129_radiation.csv
# True True
# 432.0
# 16.9
# 2006-06-20T23:00
# ano                                                      2006
# codigo_sgif                                         TM1061488
# tipo                                                Florestal
# distrito                                            Vila Real
# concelho                                           Montalegre
# freguesia                                        Sarraquinhos
# local                        Pedrario/Sarraquinhos (Pedrario)
# ine                                                    170629
# x                                                      240863
# y                                                      537880
# data_alerta                                        2006-09-08
# hora_alerta                                          17:52:00
# data_extincao                                      2006-09-08
# hora_extincao                                        20:35:00
# data_primeira_intervencao                          2006-09-08
# hora_primeira_intervencao                            18:05:00
# fonte_alerta                                               PV
# nut                                                PT11080929
# area_povoamento                                           0.0
# area_mato                                                 2.0
# area_agricola                                             0.0
# area_pov_mato                                             2.0
# area_total                                                2.0
# reacendimento                                               0
# queimada                                                    0
# falso_alarme                                                0
# fogacho                                                     0
# incendio                                                    1
# agricola                                                    0
# perimetro                                             Barroso
# aps                                                       NaN
# causa                                                     NaN
# tipo_causa                                                NaN
# LAT                                                 41.809524
# LON                                                 -7.640711
# Name: 15, dtype: object
# 2006-09-08_41.8095242_-7.6407113.csv 2006-09-08_41.8095242_-7.6407113_radiation.csv
# True True
# 970.0
# 25.7
# 2006-09-08T17:00
# ano                                2006
# codigo_sgif                    TM206122
# tipo                          Florestal
# distrito                       Bragança
# concelho                      Mogadouro
# freguesia                     Mogadouro
# local                              Zava
# ine                               40810
# x                                318884
# y                                484294
# data_alerta                  2006-04-28
# hora_alerta                    15:40:00
# data_extincao                2006-04-28
# hora_extincao                  17:10:00
# data_primeira_intervencao    2006-04-28
# hora_primeira_intervencao      15:40:00
# fonte_alerta                  Populares
# nut                          PT11080810
# area_povoamento                    0.25
# area_mato                           0.0
# area_agricola                       0.0
# area_pov_mato                      0.25
# area_total                         0.25
# reacendimento                         0
# queimada                              0
# falso_alarme                          0
# fogacho                               1
# incendio                              0
# agricola                              0
# perimetro                           NaN
# aps                                 NaN
# causa                               NaN
# tipo_causa                          NaN
# LAT                           41.327537
# LON                           -6.708026
# Name: 16, dtype: object
# 2006-04-28_41.3275372_-6.708026371672676.csv 2006-04-28_41.3275372_-6.708026371672676_radiation.csv
# True True
# 730.0
# 18.8
# 2006-04-28T15:00
