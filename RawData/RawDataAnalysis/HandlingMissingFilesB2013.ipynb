# %%
import pandas as pd
import requests
import ast
import os
# Out:
# /tmp/ipykernel_3775/1817075740.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
import pandas as pd
_year = 2009
dfMissing = pd.read_csv(f'error_rows{_year}.csv')
print(len(dfMissing))
# Out:
# 13

# %%
print(len([f for f in os.listdir(f'MissingFiles{_year}') if os.path.isfile(os.path.join(f'MissingFiles{_year}', f))]))
# Out:
# 0

# %%
_year = 2009
dfMissing = pd.read_csv(f'error_rows{_year}.csv')
print(len(dfMissing))
for r in range(0, len(dfMissing)):
    row = dfMissing.iloc[r]

    LAT = row['LAT']
    _DATA = row['data_alerta']
    LON = row['LON']

    _fileName_radiation = _DATA + f"_{LAT}_{LON}_radiation"
    _fileName = _DATA + f"_{LAT}_{LON}"


    #RawData/RawDataAnalysis/MissingFiles2012
    #url_rad = f"https://archive-api.open-meteo.com/v1/archive?latitude={LAT}&longitude={LON}&start_date={_DATA}&end_date={_DATA}&hourly=shortwave_radiation,direct_radiation,diffuse_radiation,direct_normal_irradiance,global_tilted_irradiance,terrestrial_radiation,shortwave_radiation_instant,direct_radiation_instant,diffuse_radiation_instant,direct_normal_irradiance_instant,global_tilted_irradiance_instant,terrestrial_radiation_instant"
    url = f"https://archive-api.open-meteo.com/v1/archive?latitude={LAT}&longitude={LON}&start_date={_DATA}&end_date={_DATA}&hourly=temperature_2m,relative_humidity_2m,dew_point_2m,apparent_temperature,precipitation,rain,snowfall,snow_depth,weather_code,pressure_msl,surface_pressure,cloud_cover,cloud_cover_low,cloud_cover_mid,cloud_cover_high,et0_fao_evapotranspiration,vapour_pressure_deficit,wind_speed_10m,wind_speed_100m,wind_direction_10m,wind_direction_100m,wind_gusts_10m,soil_temperature_0_to_7cm,soil_temperature_7_to_28cm,soil_temperature_28_to_100cm,soil_temperature_100_to_255cm,soil_moisture_0_to_7cm,soil_moisture_7_to_28cm,soil_moisture_28_to_100cm,soil_moisture_100_to_255cm,is_day,sunshine_duration,shortwave_radiation_instant,direct_radiation_instant,diffuse_radiation_instant,direct_normal_irradiance_instant,global_tilted_irradiance_instant,terrestrial_radiation_instant&timezone=GMT"
    response = requests.get(url)
    #response_rad = requests.get(url_rad)

    print(response.status_code)

    if((response.status_code == 200)):
        data = response.json()
        #data_rad = response_rad.json()

        df = pd.json_normalize(data)
        df.to_csv(f"MissingFiles{_year}/{_fileName}.csv", index=False)

        #df_rad = pd.json_normalize(data_rad)
        #df_rad.to_csv(f"MissingFiles{_year}/{_fileName_radiation}.csv", index=False)
    else:
        print("Error row:", str(r))
# Out:
# 14
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200
# 200

# %%
current_dir = os.getcwd()
root_dir = os.path.dirname(os.path.dirname(current_dir))
_RAWFIRESPATH = f"{root_dir}/RawData/Historical_FiresRAW"

_year = 2005
_file = f"{_RAWFIRESPATH}/{_year}/2005-01-01_37.7388357_-8.750062888101874.csv"
df = pd.read_csv(f"{_file}")

column_names = df.columns.tolist()

column_names = df.columns.tolist()

columns_to_remove = [col for col in column_names if 'hourly_units' in col]
columns_to_remove.extend(['latitude', 'longitude', 'generationtime_ms', 'utc_offset_seconds', 'timezone', 'timezone_abbreviation'])

df = df.drop(columns=columns_to_remove)

updated_column_names = df.columns.tolist()

_file_radiation = _file.replace(".csv", "_radiation.csv")
df = pd.read_csv(f"{_file_radiation}")

df = pd.read_csv(f"{_file_radiation}")
column_names = df.columns.tolist()
print(column_names)

column_names = df.columns.tolist()

columns_to_remove = [col for col in column_names if 'hourly_units' in col]
columns_to_remove.extend(['latitude', 'longitude', 'generationtime_ms', 'utc_offset_seconds', 'timezone', 'timezone_abbreviation', 'elevation', 'hourly.time', 'hourly.global_tilted_irradiance_instant', 'hourly.diffuse_radiation_instant', 'hourly.terrestrial_radiation_instant', 'hourly.direct_radiation_instant', 'hourly.shortwave_radiation_instant', 'hourly.direct_normal_irradiance_instant'])

df = df.drop(columns=columns_to_remove)

updated_column_names_radiation = df.columns.tolist()
print(updated_column_names_radiation)

set1 = set(updated_column_names_radiation)
set2 = set(updated_column_names)

common_elements = set1 & set2

print(common_elements)
# Out:
# ['latitude', 'longitude', 'generationtime_ms', 'utc_offset_seconds', 'timezone', 'timezone_abbreviation', 'elevation', 'hourly_units.time', 'hourly_units.shortwave_radiation', 'hourly_units.direct_radiation', 'hourly_units.diffuse_radiation', 'hourly_units.direct_normal_irradiance', 'hourly_units.global_tilted_irradiance', 'hourly_units.terrestrial_radiation', 'hourly_units.shortwave_radiation_instant', 'hourly_units.direct_radiation_instant', 'hourly_units.diffuse_radiation_instant', 'hourly_units.direct_normal_irradiance_instant', 'hourly_units.global_tilted_irradiance_instant', 'hourly_units.terrestrial_radiation_instant', 'hourly.time', 'hourly.shortwave_radiation', 'hourly.direct_radiation', 'hourly.diffuse_radiation', 'hourly.direct_normal_irradiance', 'hourly.global_tilted_irradiance', 'hourly.terrestrial_radiation', 'hourly.shortwave_radiation_instant', 'hourly.direct_radiation_instant', 'hourly.diffuse_radiation_instant', 'hourly.direct_normal_irradiance_instant', 'hourly.global_tilted_irradiance_instant', 'hourly.terrestrial_radiation_instant']
# ['hourly.shortwave_radiation', 'hourly.direct_radiation', 'hourly.diffuse_radiation', 'hourly.direct_normal_irradiance', 'hourly.global_tilted_irradiance', 'hourly.terrestrial_radiation']
# set()

# %%
_year = 2009

df = pd.read_csv("b2009y.csv")

print(df.head())

dfsourcex = pd.read_csv(f'error_rows{_year}.csv')

for r in range(0, len(dfsourcex)):

    row = dfsourcex.iloc[r]


    print(row)

    DISTRICTO = row['distrito']
    CONCELHO = row['concelho']
    FREGUESIA = row['freguesia']
    LOCAL = row['local']
    LAT = row['LAT']
    _DATA = row['data_alerta']
    LON = row['LON']
    CAUSA = row['tipo_causa']
    ANO = row['ano']
    hora = row['hora_alerta']
    HORA = int(str(hora).split(":")[0])

    if pd.isna(LOCAL):
        LOCAL = 'NC'

    if pd.isna(CAUSA):
        CAUSA = 'NC'

    MeteorologyFile = False
    RadiationFile = False


    _fileName = _DATA + f"_{LAT}_{LON}.csv"
    _fileName_radiation = _DATA + f"_{LAT}_{LON}_radiation.csv"

    print(_fileName, _fileName_radiation)

    # MissingFiles{_year}/{_fileName_radiation}.csv
    isExistMeteorology = os.path.isfile(f'MissingFiles{_year}/{_fileName}')
    if(isExistMeteorology):
        MeteorologyFile = True
    else:
        row_df = pd.DataFrame(row).transpose()  # Convert row (Series) to DataFrame
        row_df.to_csv(f'error_rowsX{_year}.csv', mode='a', header=False, index=False)
        
        continue

    isExistRadiation = os.path.isfile(f'MissingFiles{_year}/{_fileName_radiation}')
    if(isExistRadiation):
        RadiationFile = True
    else:
        row_df = pd.DataFrame(row).transpose()  # Convert row (Series) to DataFrame
        row_df.to_csv(f'error_rowsX{_year}.csv', mode='a', header=False, index=False)
        
        continue

    print(isExistMeteorology, RadiationFile)

    if(MeteorologyFile and RadiationFile):
        try:
            dfMet = pd.read_csv(f"MissingFiles{_year}/{_fileName}")
            dfRad = pd.read_csv(f"MissingFiles{_year}/{_fileName_radiation}")
        except Exception as e:
            print(e)
            row_df = pd.DataFrame(row).transpose()  # Convert row (Series) to DataFrame
            row_df.to_csv(f'error_rowsX{_year}.csv', mode='a', header=False, index=False)
            
            continue

        print(dfMet['elevation'].iloc[0])

        list_from_string = ast.literal_eval(dfMet[updated_column_names[2]].iloc[0])[HORA]

        print(list_from_string)

        list_from_string = ast.literal_eval(dfMet[updated_column_names[1]].iloc[0])[HORA]

        print(list_from_string)

        new_data = {
            'year': ANO,
            'date': f"{_DATA}",
            'district': DISTRICTO,
            'municipality': CONCELHO,
            'parish': FREGUESIA,
            'local': LOCAL,
            'latitude': LAT,
            'longitude': LON,
            'cause': CAUSA,
            'elevation': dfMet['elevation'].iloc[0]
        }

        try:
            for i in range(1, len(updated_column_names)):
                new_data[updated_column_names[i]] = ast.literal_eval(dfMet[updated_column_names[i]].iloc[0])[HORA]
        except Exception as e:
            print("->", e)

        try:
            for i in range(0, len(updated_column_names_radiation)):
                new_data[updated_column_names_radiation[i]] = ast.literal_eval(dfRad[updated_column_names_radiation[i]].iloc[0])[HORA]
        except Exception as e:
            print("-x", e)

        new_df = pd.DataFrame(new_data, index=[0])

        new_df.to_csv('b2009y.csv', mode='a', header=False, index=False)
# Out:
# Empty DataFrame
# Columns: [year, date, district, municipality, parish, local, latitude, longitude, cause, elevation, hourly.time, hourly.temperature_2m, hourly.relative_humidity_2m, hourly.dew_point_2m, hourly.apparent_temperature, hourly.precipitation, hourly.rain, hourly.snowfall, hourly.snow_depth, hourly.weather_code, hourly.pressure_msl, hourly.surface_pressure, hourly.cloud_cover, hourly.cloud_cover_low, hourly.cloud_cover_mid, hourly.cloud_cover_high, hourly.et0_fao_evapotranspiration, hourly.vapour_pressure_deficit, hourly.wind_speed_10m, hourly.wind_speed_100m, hourly.wind_direction_10m, hourly.wind_direction_100m, hourly.wind_gusts_10m, hourly.soil_temperature_0_to_7cm, hourly.soil_temperature_7_to_28cm, hourly.soil_temperature_28_to_100cm, hourly.soil_temperature_100_to_255cm, hourly.soil_moisture_0_to_7cm, hourly.soil_moisture_7_to_28cm, hourly.soil_moisture_28_to_100cm, hourly.soil_moisture_100_to_255cm, hourly.is_day, hourly.sunshine_duration, hourly.shortwave_radiation_instant, hourly.direct_radiation_instant, hourly.diffuse_radiation_instant, hourly.direct_normal_irradiance_instant, hourly.global_tilted_irradiance_instant, hourly.terrestrial_radiation_instant, hourly.shortwave_radiation, hourly.direct_radiation, hourly.diffuse_radiation, hourly.direct_normal_irradiance, hourly.global_tilted_irradiance, hourly.terrestrial_radiation]
# Index: []
#
# [0 rows x 55 columns]
# ano                                                   2010
# codigo_sgif                                       BL310420
# tipo                                             Florestal
# distrito                                            Aveiro
# concelho                              Santa Maria da Feira
# freguesia                                          Romariz
# local                        Carvalhal ( Rua do Espadanal)
# ine                                                  10922
# x                                                 168630.0
# y                                                 443145.0
# data_alerta                                     2010-06-05
# hora_alerta                                       18:25:00
# data_extincao                                   2010-06-05
# hora_extincao                                     20:00:00
# data_primeira_intervencao                       2010-06-05
# hora_primeira_intervencao                         18:35:00
# fonte_alerta                                     Populares
# nut                                             PT11060222
# area_povoamento                                       0.05
# area_mato                                              0.0
# area_agricola                                          0.0
# area_pov_mato                                         0.05
# area_total                                            0.05
# reacendimento                                            1
# queimada                                                 0
# falso_alarme                                             0
# fogacho                                                  1
# incendio                                                 0
# agricola                                                 0
# perimetro                                              NaN
# aps                                                    NaN
# causa                                                  NaN
# tipo_causa                                             NaN
# LAT                                              40.962303
# LON                                              -8.438364
# Name: 0, dtype: object
# 2010-06-05_40.9623033_-8.4383638.csv 2010-06-05_40.9623033_-8.4383638_radiation.csv
# True True
# 216.0
# 18.5
# 2010-06-05T18:00
# ano                                                   2010
# codigo_sgif                                       DM410230
# tipo                                             Florestal
# distrito                                             Braga
# concelho                                            VIZELA
# freguesia                      Caldas De Vizela (são João)
# local                        PARADELA (S. JOAO) (São João)
# ine                                                  31402
# x                                                 185323.0
# y                                                 489083.0
# data_alerta                                     2010-04-11
# hora_alerta                                       11:54:00
# data_extincao                                   2010-04-11
# hora_extincao                                     12:50:00
# data_primeira_intervencao                       2010-04-11
# hora_primeira_intervencao                         12:00:00
# fonte_alerta                                     Populares
# nut                                             PT11030702
# area_povoamento                                        0.0
# area_mato                                             0.11
# area_agricola                                          0.0
# area_pov_mato                                         0.11
# area_total                                            0.11
# reacendimento                                            0
# queimada                                                 0
# falso_alarme                                             0
# fogacho                                                  1
# incendio                                                 0
# agricola                                                 0
# perimetro                                              NaN
# aps                                                    NaN
# causa                                                  NaN
# tipo_causa                                             NaN
# LAT                                              41.366036
# LON                                              -8.314106
# Name: 1, dtype: object
# 2010-04-11_41.3660355_-8.314106448896961.csv 2010-04-11_41.3660355_-8.314106448896961_radiation.csv
# True True
# 186.0
# 20.6
# 2010-04-11T11:00
# ano                                  2010
# codigo_sgif                      DM210782
# tipo                            Florestal
# distrito                            Porto
# concelho                          Paredes
# freguesia                    Duas Igrejas
# local                                Vale
# ine                                131010
# x                                173265.0
# y                                470459.0
# data_alerta                    2010-06-21
# hora_alerta                      17:23:00
# data_extincao                  2010-06-21
# hora_extincao                    19:56:00
# data_primeira_intervencao      2010-06-21
# hora_primeira_intervencao        17:24:00
# fonte_alerta                    Populares
# nut                            PT11051210
# area_povoamento                       0.0
# area_mato                            0.01
# area_agricola                         0.0
# area_pov_mato                        0.01
# area_total                           0.01
# reacendimento                           0
# queimada                                0
# falso_alarme                            0
# fogacho                                 1
# incendio                                0
# agricola                                0
# perimetro                             NaN
# aps                                   NaN
# causa                                 6.0
# tipo_causa                   Desconhecida
# LAT                             41.230974
# LON                              -8.37726
# Name: 2, dtype: object
# 2010-06-21_41.230974_-8.3772602.csv 2010-06-21_41.230974_-8.3772602_radiation.csv
# True True
# 332.0
# 24.8
# 2010-06-21T17:00
# ano                                           2010
# codigo_sgif                               TM110144
# tipo                                     Florestal
# distrito                                 Vila Real
# concelho                                     Alijó
# freguesia                          Vilar de Maçada
# local                        Franselos (Francelos)
# ine                                         170118
# x                                         251833.0
# y                                         485275.0
# data_alerta                             2010-03-17
# hora_alerta                               18:06:00
# data_extincao                           2010-03-17
# hora_extincao                             21:15:00
# data_primeira_intervencao               2010-03-17
# hora_primeira_intervencao                 18:20:00
# fonte_alerta                             Populares
# nut                                     PT11070118
# area_povoamento                                0.0
# area_mato                                     0.01
# area_agricola                                  0.0
# area_pov_mato                                 0.01
# area_total                                    0.01
# reacendimento                                    0
# queimada                                         0
# falso_alarme                                     0
# fogacho                                          1
# incendio                                         0
# agricola                                         0
# perimetro                                      NaN
# aps                                            NaN
# causa                                          NaN
# tipo_causa                                     NaN
# LAT                                      41.326435
# LON                                      -7.489572
# Name: 3, dtype: object
# 2010-03-17_41.326435_-7.489572.csv 2010-03-17_41.326435_-7.489572_radiation.csv
# True True
# 780.0
# 12.7
# 2010-03-17T18:00
# ano                                             2010
# codigo_sgif                                 TM110111
# tipo                                       Florestal
# distrito                                   Vila Real
# concelho                                    Valpaços
# freguesia                    Carrazedo de Montenegro
# local                                        Argemil
# ine                                           171207
# x                                           259634.0
# y                                           512812.0
# data_alerta                               2010-01-29
# hora_alerta                                 18:40:00
# data_extincao                             2010-01-29
# hora_extincao                               19:00:00
# data_primeira_intervencao                 2010-01-29
# hora_primeira_intervencao                   18:45:00
# fonte_alerta                               Populares
# nut                                       PT11081107
# area_povoamento                                  0.0
# area_mato                                       0.01
# area_agricola                                    0.0
# area_pov_mato                                   0.01
# area_total                                      0.01
# reacendimento                                      0
# queimada                                           0
# falso_alarme                                       0
# fogacho                                            1
# incendio                                           0
# agricola                                           0
# perimetro                                        NaN
# aps                                              NaN
# causa                                            NaN
# tipo_causa                                       NaN
# LAT                                        41.568214
# LON                                        -7.425471
# Name: 4, dtype: object
# 2010-01-29_41.56821365_-7.425471011792769.csv 2010-01-29_41.56821365_-7.425471011792769_radiation.csv
# True True
# 762.0
# 5.4
# 2010-01-29T18:00
# ano                                              2010
# codigo_sgif                                   DM21094
# tipo                                        Florestal
# distrito                                        Porto
# concelho                            Paços de Ferreira
# freguesia                                    Ferreira
# local                        LUG. QUINTELA (FERREIRA)
# ine                                            130905
# x                                            182001.0
# y                                            477250.0
# data_alerta                                2010-03-17
# hora_alerta                                  19:00:00
# data_extincao                              2010-03-17
# hora_extincao                                20:22:00
# data_primeira_intervencao                  2010-03-17
# hora_primeira_intervencao                    19:07:00
# fonte_alerta                                Populares
# nut                                        PT11051105
# area_povoamento                                   0.0
# area_mato                                         0.2
# area_agricola                                     0.0
# area_pov_mato                                     0.2
# area_total                                        0.2
# reacendimento                                       0
# queimada                                            0
# falso_alarme                                        0
# fogacho                                             1
# incendio                                            0
# agricola                                            0
# perimetro                                         NaN
# aps                                               NaN
# causa                                             NaN
# tipo_causa                                        NaN
# LAT                                         41.266371
# LON                                         -8.344563
# Name: 5, dtype: object
# 2010-03-17_41.2663712_-8.3445627.csv 2010-03-17_41.2663712_-8.3445627_radiation.csv
# True True
# 331.0
# 12.7
# 2010-03-17T19:00
# ano                                                         2010
# codigo_sgif                                             DM410233
# tipo                                                   Florestal
# distrito                                                   Braga
# concelho                                                  VIZELA
# freguesia                            Caldas De Vizela (são João)
# local                        VILAR (VIZELA S. JOÃO) (Entrevilar)
# ine                                                        31402
# x                                                       184439.0
# y                                                       489456.0
# data_alerta                                           2010-04-11
# hora_alerta                                             15:31:00
# data_extincao                                         2010-04-11
# hora_extincao                                           16:15:00
# data_primeira_intervencao                             2010-04-11
# hora_primeira_intervencao                               15:40:00
# fonte_alerta                                           Populares
# nut                                                   PT11030702
# area_povoamento                                              0.0
# area_mato                                                   0.05
# area_agricola                                                0.0
# area_pov_mato                                               0.05
# area_total                                                  0.05
# reacendimento                                                  0
# queimada                                                       0
# falso_alarme                                                   0
# fogacho                                                        1
# incendio                                                       0
# agricola                                                       0
# perimetro                                                    NaN
# aps                                                          NaN
# causa                                                        NaN
# tipo_causa                                                   NaN
# LAT                                                    41.366036
# LON                                                    -8.314106
# Name: 6, dtype: object
# 2010-04-11_41.3660355_-8.314106448896961.csv 2010-04-11_41.3660355_-8.314106448896961_radiation.csv
# True True
# 186.0
# 23.0
# 2010-04-11T15:00
# ano                                                      2010
# codigo_sgif                                          DM410317
# tipo                                                Florestal
# distrito                                                Braga
# concelho                                           Vila Verde
# freguesia                                             Valdreu
# local                        CABANINHAS(VALDREU) (Cabaninhas)
# ine                                                     31355
# x                                                    185228.0
# y                                                    531204.0
# data_alerta                                        2010-05-05
# hora_alerta                                          01:05:00
# data_extincao                                      2010-05-05
# hora_extincao                                        08:10:00
# data_primeira_intervencao                          2010-05-05
# hora_primeira_intervencao                            01:28:00
# fonte_alerta                                        Populares
# nut                                                PT11020655
# area_povoamento                                           3.0
# area_mato                                                 9.3
# area_agricola                                             0.0
# area_pov_mato                                            12.3
# area_total                                               12.3
# reacendimento                                               0
# queimada                                                    0
# falso_alarme                                                0
# fogacho                                                     0
# incendio                                                    1
# agricola                                                    0
# perimetro                                       Serra amarela
# aps                                                       NaN
# causa                                                     6.0
# tipo_causa                                       Desconhecida
# LAT                                                 41.726337
# LON                                                 -8.316646
# Name: 7, dtype: object
# 2010-05-05_41.7263368_-8.316646445788313.csv 2010-05-05_41.7263368_-8.316646445788313_radiation.csv
# True True
# 254.0
# 5.2
# 2010-05-05T01:00
# ano                                          2010
# codigo_sgif                              TM210107
# tipo                                    Florestal
# distrito                                 Bragança
# concelho                     Macedo de Cavaleiros
# freguesia                                Cortiços
# local                                   Cernadela
# ine                                         40510
# x                                        291280.0
# y                                        504877.0
# data_alerta                            2010-02-11
# hora_alerta                              17:12:00
# data_extincao                          2010-02-11
# hora_extincao                            20:38:00
# data_primeira_intervencao              2010-02-11
# hora_primeira_intervencao                17:30:00
# fonte_alerta                            Populares
# nut                                    PT11080510
# area_povoamento                               0.0
# area_mato                                     2.0
# area_agricola                                 0.0
# area_pov_mato                                 2.0
# area_total                                    2.0
# reacendimento                                   0
# queimada                                        0
# falso_alarme                                    0
# fogacho                                         0
# incendio                                        1
# agricola                                        0
# perimetro                                     NaN
# aps                                           NaN
# causa                                         NaN
# tipo_causa                                    NaN
# LAT                                     41.517495
# LON                                     -7.021834
# Name: 8, dtype: object
# 2010-02-11_41.517495_-7.0218345.csv 2010-02-11_41.517495_-7.0218345_radiation.csv
# True True
# 492.0
# 6.6
# 2010-02-11T17:00
# ano                                                           2010
# codigo_sgif                                               DM410712
# tipo                                                     Florestal
# distrito                                                     Braga
# concelho                                          Póvoa de Lanhoso
# freguesia                                                Travassos
# local                        CASTANHEIRA (TRAVASSOS) (Castanheira)
# ine                                                          30927
# x                                                         189162.0
# y                                                         514126.0
# data_alerta                                             2010-07-15
# hora_alerta                                               14:46:00
# data_extincao                                           2010-07-15
# hora_extincao                                             19:45:00
# data_primeira_intervencao                               2010-07-15
# hora_primeira_intervencao                                 14:55:00
# fonte_alerta                                             Populares
# nut                                                     PT11030327
# area_povoamento                                               0.05
# area_mato                                                      0.2
# area_agricola                                                  0.0
# area_pov_mato                                                 0.25
# area_total                                                    0.25
# reacendimento                                                    0
# queimada                                                         0
# falso_alarme                                                     0
# fogacho                                                          1
# incendio                                                         0
# agricola                                                         0
# perimetro                                                      NaN
# aps                                                            NaN
# causa                                                          NaN
# tipo_causa                                                     NaN
# LAT                                                      41.575693
# LON                                                       -8.20253
# Name: 9, dtype: object
# 2010-07-15_41.57569275_-8.202529903910126.csv 2010-07-15_41.57569275_-8.202529903910126_radiation.csv
# True True
# 282.0
# 21.9
# 2010-07-15T14:00
# ano                                        2010
# codigo_sgif                           DM2101645
# tipo                                  Florestal
# distrito                                  Porto
# concelho                     Marco de Canaveses
# freguesia                                Favões
# local                                    Requim
# ine                                      130706
# x                                      191140.0
# y                                      460052.0
# data_alerta                          2010-07-17
# hora_alerta                            14:38:00
# data_extincao                        2010-07-17
# hora_extincao                          17:55:00
# data_primeira_intervencao            2010-07-17
# hora_primeira_intervencao              14:44:00
# fonte_alerta                          Populares
# nut                                  PT11050906
# area_povoamento                             0.0
# area_mato                                  0.05
# area_agricola                               0.0
# area_pov_mato                              0.05
# area_total                                 0.05
# reacendimento                                 0
# queimada                                      0
# falso_alarme                                  0
# fogacho                                       1
# incendio                                      0
# agricola                                      0
# perimetro                                   NaN
# aps                                         NaN
# causa                                       NaN
# tipo_causa                                  NaN
# LAT                                   41.115184
# LON                                   -8.231846
# Name: 10, dtype: object
# 2010-07-17_41.1151838_-8.2318458.csv 2010-07-17_41.1151838_-8.2318458_radiation.csv
# True True
# 190.0
# 29.6
# 2010-07-17T14:00
# ano                                      2010
# codigo_sgif                         BL3101053
# tipo                                Florestal
# distrito                               Aveiro
# concelho                       Sever do Vouga
# freguesia                    Couto de Esteves
# local                               Vilarinho
# ine                                     11702
# x                                    184308.0
# y                                    409803.0
# data_alerta                        2010-07-19
# hora_alerta                          15:31:00
# data_extincao                      2010-07-19
# hora_extincao                        18:40:00
# data_primeira_intervencao          2010-07-19
# hora_primeira_intervencao            15:45:00
# fonte_alerta                        Populares
# nut                                PT12011102
# area_povoamento                          0.08
# area_mato                                 0.0
# area_agricola                             0.0
# area_pov_mato                            0.08
# area_total                               0.08
# reacendimento                               0
# queimada                                    0
# falso_alarme                                0
# fogacho                                     1
# incendio                                    0
# agricola                                    0
# perimetro                                 NaN
# aps                                       NaN
# causa                                     6.0
# tipo_causa                       Desconhecida
# LAT                                 40.745494
# LON                                 -8.316747
# Name: 11, dtype: object
# 2010-07-19_40.7454943_-8.3167469.csv 2010-07-19_40.7454943_-8.3167469_radiation.csv
# True True
# 197.0
# 28.5
# 2010-07-19T15:00
# ano                                                          2010
# codigo_sgif                                              DM210283
# tipo                                                    Florestal
# distrito                                                    Porto
# concelho                                                 Gondomar
# freguesia                                       São Pedro da Cova
# local                        RUA FERNÃO LOPES (SÃO PEDRO DA COVA)
# ine                                                        130410
# x                                                        168893.0
# y                                                        465224.0
# data_alerta                                            2010-05-02
# hora_alerta                                              15:06:00
# data_extincao                                          2010-05-02
# hora_extincao                                            17:43:00
# data_primeira_intervencao                              2010-05-02
# hora_primeira_intervencao                                15:10:00
# fonte_alerta                                            Populares
# nut                                                    PT11040210
# area_povoamento                                               0.1
# area_mato                                                     0.0
# area_agricola                                                 0.0
# area_pov_mato                                                 0.1
# area_total                                                    0.1
# reacendimento                                                   0
# queimada                                                        0
# falso_alarme                                                    0
# fogacho                                                         1
# incendio                                                        0
# agricola                                                        0
# perimetro                                                     NaN
# aps                                                           NaN
# causa                                                         NaN
# tipo_causa                                                    NaN
# LAT                                                     41.146306
# LON                                                     -8.513812
# Name: 12, dtype: object
# 2010-05-02_41.146305850000005_-8.513812231973976.csv 2010-05-02_41.146305850000005_-8.513812231973976_radiation.csv
# True True
# 128.0
# 18.0
# 2010-05-02T15:00
# ano                                                                       2010
# codigo_sgif                                                           RO310500
# tipo                                                                 Florestal
# distrito                                                               Setúbal
# concelho                                                               Palmela
# freguesia                                                       Quinta do Anjo
# local                        VACARIA JUNTO Á FÁBRICA CODIMETAL (QUINTA DO A...
# ine                                                                     150804
# x                                                                     129446.0
# y                                                                     178108.0
# data_alerta                                                         2010-07-19
# hora_alerta                                                           22:12:00
# data_extincao                                                       2010-07-19
# hora_extincao                                                         23:20:00
# data_primeira_intervencao                                           2010-07-19
# hora_primeira_intervencao                                             22:23:00
# fonte_alerta                                                         Populares
# nut                                                                 PT13030604
# area_povoamento                                                            0.0
# area_mato                                                                0.005
# area_agricola                                                              0.0
# area_pov_mato                                                            0.005
# area_total                                                               0.005
# reacendimento                                                                0
# queimada                                                                     0
# falso_alarme                                                                 0
# fogacho                                                                      1
# incendio                                                                     0
# agricola                                                                     0
# perimetro                                                                  NaN
# aps                                                                        NaN
# causa                                                                      NaN
# tipo_causa                                                                 NaN
# LAT                                                                  38.580326
# LON                                                                  -8.980884
# Name: 13, dtype: object
# 2010-07-19_38.5803261_-8.980884492896589.csv 2010-07-19_38.5803261_-8.980884492896589_radiation.csv
# True True
# 46.0
# 18.9
# 2010-07-19T22:00
# ano                                          2010
# codigo_sgif                              DM210802
# tipo                                    Florestal
# distrito                                    Porto
# concelho                                 Amarante
# freguesia                                 Cepelos
# local                        GERALDES (REBORDELO)
# ine                                        130110
# x                                        212318.0
# y                                        486050.0
# data_alerta                            2010-06-22
# hora_alerta                              17:44:00
# data_extincao                          2010-06-22
# hora_extincao                            19:15:00
# data_primeira_intervencao              2010-06-22
# hora_primeira_intervencao                17:50:00
# fonte_alerta                            Populares
# nut                                    PT11050110
# area_povoamento                               0.0
# area_mato                                    0.13
# area_agricola                                 0.0
# area_pov_mato                                0.13
# area_total                                   0.13
# reacendimento                                   0
# queimada                                        0
# falso_alarme                                    0
# fogacho                                         1
# incendio                                        0
# agricola                                        0
# perimetro                                     NaN
# aps                                           NaN
# causa                                         NaN
# tipo_causa                                    NaN
# LAT                                     41.255033
# LON                                     -8.082315
# Name: 14, dtype: object
# 2010-06-22_41.2550333_-8.0823148.csv 2010-06-22_41.2550333_-8.0823148_radiation.csv
# True True
# 199.0
# 28.4
# 2010-06-22T17:00
# ano                                        2010
# codigo_sgif                           DM2101651
# tipo                                  Florestal
# distrito                                  Porto
# concelho                      Vila Nova de Gaia
# freguesia                               Serzedo
# local                        Rua das Catazendas
# ine                                      131721
# x                                      159937.0
# y                                      451940.0
# data_alerta                          2010-07-17
# hora_alerta                            15:30:00
# data_extincao                        2010-07-17
# hora_extincao                          17:43:00
# data_primeira_intervencao            2010-07-17
# hora_primeira_intervencao              15:36:00
# fonte_alerta                                117
# nut                                  PT11040921
# area_povoamento                             0.2
# area_mato                                   0.0
# area_agricola                               0.0
# area_pov_mato                               0.2
# area_total                                  0.2
# reacendimento                                 0
# queimada                                      0
# falso_alarme                                  0
# fogacho                                       1
# incendio                                      0
# agricola                                      0
# perimetro                                   NaN
# aps                                         NaN
# causa                                       NaN
# tipo_causa                                  NaN
# LAT                                   41.035705
# LON                                   -8.609649
# Name: 15, dtype: object
# 2010-07-17_41.0357053_-8.609649.csv 2010-07-17_41.0357053_-8.609649_radiation.csv
# True True
# 99.0
# 27.6
# 2010-07-17T15:00
# ano                                          2010
# codigo_sgif                              TM110211
# tipo                                    Florestal
# distrito                                Vila Real
# concelho                                Vila Real
# freguesia                    Vilarinho de Samardã
# local                                      Covelo
# ine                                        171430
# x                                        230080.0
# y                                        481410.0
# data_alerta                            2010-04-11
# hora_alerta                              20:23:00
# data_extincao                          2010-04-11
# hora_extincao                            23:00:00
# data_primeira_intervencao              2010-04-11
# hora_primeira_intervencao                20:50:00
# fonte_alerta                            Populares
# nut                                    PT11071930
# area_povoamento                               0.0
# area_mato                                     2.0
# area_agricola                                 0.0
# area_pov_mato                                 2.0
# area_total                                    2.0
# reacendimento                                   0
# queimada                                        0
# falso_alarme                                    0
# fogacho                                         0
# incendio                                        1
# agricola                                        0
# perimetro                                     NaN
# aps                                           NaN
# causa                                         NaN
# tipo_causa                                    NaN
# LAT                                     41.354016
# LON                                     -7.721729
# Name: 16, dtype: object
# 2010-04-11_41.3540156_-7.7217288.csv 2010-04-11_41.3540156_-7.7217288_radiation.csv
# True True
# 578.0
# 16.9
# 2010-04-11T20:00
# ano                                   2010
# codigo_sgif                        RO11015
# tipo                             Florestal
# distrito                          Santarém
# concelho                          Alpiarça
# freguesia                         Alpiarça
# local                        Frade de Cima
# ine                                 140401
# x                                 161646.0
# y                                 247183.0
# data_alerta                     2010-04-28
# hora_alerta                       16:54:00
# data_extincao                   2010-04-28
# hora_extincao                     18:34:00
# data_primeira_intervencao       2010-04-28
# hora_primeira_intervencao         17:08:00
# fonte_alerta                        Outros
# nut                             PT13050201
# area_povoamento                      0.005
# area_mato                              0.0
# area_agricola                          0.0
# area_pov_mato                        0.005
# area_total                           0.005
# reacendimento                            0
# queimada                                 0
# falso_alarme                             0
# fogacho                                  1
# incendio                                 0
# agricola                                 0
# perimetro                              NaN
# aps                                    NaN
# causa                                  NaN
# tipo_causa                             NaN
# LAT                              39.188073
# LON                              -8.565016
# Name: 17, dtype: object
# 2010-04-28_39.188073_-8.5650159.csv 2010-04-28_39.188073_-8.5650159_radiation.csv
# True True
# 71.0
# 28.6
# 2010-04-28T16:00
# ano                                                            2010
# codigo_sgif                                                 RO31057
# tipo                                                      Florestal
# distrito                                                    Setúbal
# concelho                                                    Palmela
# freguesia                                                  Poceirão
# local                        FRT ESCOLA NOVA DE POCEIRÃO (Poceirão)
# ine                                                          150805
# x                                                          147024.0
# y                                                          185250.0
# data_alerta                                              2010-05-05
# hora_alerta                                                13:57:00
# data_extincao                                            2010-05-05
# hora_extincao                                              15:08:00
# data_primeira_intervencao                                2010-05-05
# hora_primeira_intervencao                                  14:09:00
# fonte_alerta                                              Populares
# nut                                                      PT13030605
# area_povoamento                                                 0.0
# area_mato                                                      0.02
# area_agricola                                                   0.0
# area_pov_mato                                                  0.02
# area_total                                                     0.02
# reacendimento                                                     0
# queimada                                                          0
# falso_alarme                                                      0
# fogacho                                                           1
# incendio                                                          0
# agricola                                                          0
# perimetro                                                       NaN
# aps                                                             NaN
# causa                                                           NaN
# tipo_causa                                                      NaN
# LAT                                                         38.6345
# LON                                                       -8.743404
# Name: 18, dtype: object
# 2010-05-05_38.63449955_-8.743403599128786.csv 2010-05-05_38.63449955_-8.743403599128786_radiation.csv
# True True
# 40.0
# 18.6
# 2010-05-05T13:00
# ano                                                       2010
# codigo_sgif                                             AG1103
# tipo                                                 Florestal
# distrito                                                  Faro
# concelho                                                 Loulé
# freguesia                                            Quarteira
# local                        Estrada da SIC (Monte da Estrada)
# ine                                                      80805
# x                                                     206672.0
# y                                                      33611.0
# data_alerta                                         2010-05-05
# hora_alerta                                           21:28:00
# data_extincao                                       2010-05-05
# hora_extincao                                         22:50:00
# data_primeira_intervencao                           2010-05-05
# hora_primeira_intervencao                             21:46:00
# fonte_alerta                                         Populares
# nut                                                 PT15010805
# area_povoamento                                            0.0
# area_mato                                               0.0002
# area_agricola                                              0.0
# area_pov_mato                                           0.0002
# area_total                                              0.0002
# reacendimento                                                0
# queimada                                                     0
# falso_alarme                                                 0
# fogacho                                                      1
# incendio                                                     0
# agricola                                                     0
# perimetro                                                  NaN
# aps                                                        NaN
# causa                                                      NaN
# tipo_causa                                                 NaN
# LAT                                                   37.05465
# LON                                                  -8.075294
# Name: 19, dtype: object
# 2010-05-05_37.05464975_-8.075293800512178.csv 2010-05-05_37.05464975_-8.075293800512178_radiation.csv
# True True
# 4.0
# 15.4
# 2010-05-05T21:00
# ano                                                  2010
# codigo_sgif                                      TM110212
# tipo                                            Florestal
# distrito                                        Vila Real
# concelho                                           Chaves
# freguesia                                           Roriz
# local                        Cavelas (Caminho do Rivelas)
# ine                                                170325
# x                                                254731.0
# y                                                530289.0
# data_alerta                                    2010-04-11
# hora_alerta                                      20:28:00
# data_extincao                                  2010-04-11
# hora_extincao                                    23:20:00
# data_primeira_intervencao                      2010-04-11
# hora_primeira_intervencao                        20:50:00
# fonte_alerta                                          117
# nut                                            PT11080425
# area_povoamento                                       0.0
# area_mato                                             1.0
# area_agricola                                         0.0
# area_pov_mato                                         1.0
# area_total                                            1.0
# reacendimento                                           0
# queimada                                                0
# falso_alarme                                            0
# fogacho                                                 0
# incendio                                                1
# agricola                                                0
# perimetro                                             NaN
# aps                                                   NaN
# causa                                                 NaN
# tipo_causa                                            NaN
# LAT                                             41.822593
# LON                                             -7.264065
# Name: 20, dtype: object
# 2010-04-11_41.8225926_-7.2640651.csv 2010-04-11_41.8225926_-7.2640651_radiation.csv
# True True
# 852.0
# 15.6
# 2010-04-11T20:00
# ano                                  2010
# codigo_sgif                      BL210108
# tipo                            Florestal
# distrito                          Coimbra
# concelho                         Penacova
# freguesia                        Penacova
# local                           Sanguinho
# ine                                 61307
# x                                189066.0
# y                                365682.0
# data_alerta                    2010-01-27
# hora_alerta                      11:20:00
# data_extincao                  2010-01-27
# hora_extincao                    13:04:00
# data_primeira_intervencao      2010-01-27
# hora_primeira_intervencao        11:30:00
# fonte_alerta                    Populares
# nut                            PT12020707
# area_povoamento                      0.04
# area_mato                            0.01
# area_agricola                         0.0
# area_pov_mato                        0.05
# area_total                           0.05
# reacendimento                           0
# queimada                                0
# falso_alarme                            0
# fogacho                                 1
# incendio                                0
# agricola                                0
# perimetro                             NaN
# aps                                   NaN
# causa                                 6.0
# tipo_causa                   Desconhecida
# LAT                             40.259527
# LON                              -8.26148
# Name: 21, dtype: object
# 2010-01-27_40.2595271_-8.2614798.csv 2010-01-27_40.2595271_-8.2614798_radiation.csv
# True True
# 190.0
# 7.1
# 2010-01-27T11:00
# ano                                          2010
# codigo_sgif                             BL3101057
# tipo                                    Florestal
# distrito                                   Aveiro
# concelho                     Santa Maria da Feira
# freguesia                     Caldas de São Jorge
# local                                   Sé (Vale)
# ine                                         10927
# ...
# agricola                                           0
# perimetro                                        NaN
# aps                                              NaN
# causa                                            NaN
# tipo_causa                                       NaN
# LAT                                        41.134699
# LON                                         -8.30817
# Name: 47, dtype: object
# 2010-05-05_41.1346994_-8.3081701.csv 2010-05-05_41.1346994_-8.3081701_radiation.csv
# True True
# 248.0
# 5.2
# 2010-05-05T02:00
# ano                                                               2010
# codigo_sgif                                                  DM2101790
# tipo                                                         Florestal
# distrito                                                         Porto
# concelho                                             Vila Nova de Gaia
# freguesia                                                      Canelas
# local                        R. PINHEIRO MANSO (Rua do Pinheiro Manso)
# ine                                                             131703
# x                                                             164310.0
# y                                                             451991.0
# data_alerta                                                 2010-07-20
# hora_alerta                                                   17:50:00
# data_extincao                                               2010-07-20
# hora_extincao                                                 20:02:00
# data_primeira_intervencao                                   2010-07-20
# hora_primeira_intervencao                                     18:00:00
# fonte_alerta                                                 Populares
# nut                                                         PT11040903
# area_povoamento                                                   0.01
# area_mato                                                          0.0
# area_agricola                                                      0.0
# area_pov_mato                                                     0.01
# area_total                                                        0.01
# reacendimento                                                        0
# queimada                                                             0
# falso_alarme                                                         0
# fogacho                                                              1
# incendio                                                             0
# agricola                                                             0
# perimetro                                                          NaN
# aps                                                                NaN
# causa                                                              NaN
# tipo_causa                                                         NaN
# LAT                                                          41.070273
# LON                                                          -8.591553
# Name: 48, dtype: object
# 2010-07-20_41.0702729_-8.5915531.csv 2010-07-20_41.0702729_-8.5915531_radiation.csv
# True True
# 189.0
# 22.8
# 2010-07-20T17:00
# ano                                         2010
# codigo_sgif                              DM21010
# tipo                                   Florestal
# distrito                                   Porto
# concelho                      Marco de Canaveses
# freguesia                               Soalhães
# local                        L.LARDOSA (Lardosa)
# ine                                       130722
# x                                       203760.0
# y                                       467255.0
# data_alerta                           2010-03-12
# hora_alerta                             20:02:00
# data_extincao                         2010-03-12
# hora_extincao                           22:00:00
# data_primeira_intervencao             2010-03-12
# hora_primeira_intervencao               20:20:00
# fonte_alerta                           Populares
# nut                                   PT11050922
# area_povoamento                              0.0
# area_mato                                    0.1
# area_agricola                                0.0
# area_pov_mato                                0.1
# area_total                                   0.1
# reacendimento                                  0
# queimada                                       0
# falso_alarme                                   0
# fogacho                                        1
# incendio                                       0
# agricola                                       0
# perimetro                                    NaN
# aps                                          NaN
# causa                                        NaN
# tipo_causa                                   NaN
# LAT                                     41.17439
# LON                                    -8.088684
# Name: 49, dtype: object
# 2010-03-12_41.1743902_-8.0886841.csv 2010-03-12_41.1743902_-8.0886841_radiation.csv
# True True
# 288.0
# 8.2
# 2010-03-12T20:00
# ano                                                  2010
# codigo_sgif                                      BL310421
# tipo                                            Florestal
# distrito                                           Aveiro
# concelho                             Santa Maria da Feira
# freguesia                                         Romariz
# local                        Carvalhal (Rua do Espadanal)
# ine                                                 10922
# x                                                168630.0
# y                                                443145.0
# data_alerta                                    2010-06-05
# hora_alerta                                      20:25:00
# data_extincao                                  2010-06-05
# hora_extincao                                    22:15:00
# data_primeira_intervencao                      2010-06-05
# hora_primeira_intervencao                        20:35:00
# fonte_alerta                                    Populares
# nut                                            PT11060222
# area_povoamento                                     0.025
# area_mato                                             0.0
# area_agricola                                         0.0
# area_pov_mato                                       0.025
# area_total                                          0.025
# reacendimento                                           1
# queimada                                                0
# falso_alarme                                            0
# fogacho                                                 1
# incendio                                                0
# agricola                                                0
# perimetro                                             NaN
# aps                                                   NaN
# causa                                                 NaN
# tipo_causa                                            NaN
# LAT                                             40.962303
# LON                                             -8.438364
# Name: 50, dtype: object
# 2010-06-05_40.9623033_-8.4383638.csv 2010-06-05_40.9623033_-8.4383638_radiation.csv
# True True
# 216.0
# 16.1
# 2010-06-05T20:00
# ano                                                                 2010
# codigo_sgif                                                     RO210288
# tipo                                                           Florestal
# distrito                                                          Lisboa
# concelho                                                         Amadora
# freguesia                                                     Falagueira
# local                        RUA PRINCIPAL - QTA DA LAJE (Rua Principal)
# ine                                                               111505
# x                                                               106147.0
# y                                                               198025.0
# data_alerta                                                   2010-06-20
# hora_alerta                                                     23:06:00
# data_extincao                                                 2010-06-21
# hora_extincao                                                   01:42:00
# data_primeira_intervencao                                     2010-06-20
# hora_primeira_intervencao                                       23:11:00
# fonte_alerta                                                   Populares
# nut                                                           PT13020105
# area_povoamento                                                      0.0
# area_mato                                                           0.02
# area_agricola                                                        0.0
# area_pov_mato                                                       0.02
# area_total                                                          0.02
# reacendimento                                                          0
# queimada                                                               0
# falso_alarme                                                           0
# fogacho                                                                1
# incendio                                                               0
# agricola                                                               0
# perimetro                                                            NaN
# aps                                                                  NaN
# causa                                                              610.0
# tipo_causa                                                  Desconhecida
# LAT                                                            38.763274
# LON                                                            -9.221528
# Name: 51, dtype: object
# 2010-06-20_38.7632736_-9.2215285.csv 2010-06-20_38.7632736_-9.2215285_radiation.csv
# True True
# 115.0
# 16.0
# 2010-06-20T23:00
# ano                                                          2010
# codigo_sgif                                             DM2102910
# tipo                                                    Florestal
# distrito                                                    Porto
# concelho                                       Marco de Canaveses
# freguesia                                      Vila Boa de Quires
# local                        RIBEIRA DE CASTRO (Barca da Ribeira)
# ine                                                        130731
# x                                                        190271.0
# y                                                        458940.0
# data_alerta                                            2010-07-31
# hora_alerta                                              17:32:00
# data_extincao                                          2010-07-31
# hora_extincao                                            19:00:00
# data_primeira_intervencao                              2010-07-31
# hora_primeira_intervencao                                17:34:00
# fonte_alerta                                            Populares
# nut                                                    PT11050931
# area_povoamento                                               0.0
# area_mato                                                    0.05
# area_agricola                                                 0.0
# area_pov_mato                                                0.05
# area_total                                                   0.05
# reacendimento                                                   0
# queimada                                                        0
# falso_alarme                                                    0
# fogacho                                                         1
# incendio                                                        0
# agricola                                                        0
# perimetro                                                     NaN
# aps                                                           NaN
# causa                                                         NaN
# tipo_causa                                                    NaN
# LAT                                                     41.202847
# LON                                                     -8.204764
# Name: 52, dtype: object
# 2010-07-31_41.2028475_-8.2047635.csv 2010-07-31_41.2028475_-8.2047635_radiation.csv
# True True
# 275.0
# 29.4
# 2010-07-31T17:00
# ano                                        2010
# codigo_sgif                           DM2102894
# tipo                                  Florestal
# distrito                                  Porto
# concelho                     Marco de Canaveses
# freguesia                    Vila Boa de Quires
# local                                      Gaia
# ine                                      130731
# x                                      193934.0
# y                                      469954.0
# data_alerta                          2010-07-31
# hora_alerta                            15:28:00
# data_extincao                        2010-08-01
# hora_extincao                          04:52:00
# data_primeira_intervencao            2010-07-31
# hora_primeira_intervencao              15:30:00
# fonte_alerta                          Populares
# nut                                  PT11050931
# area_povoamento                             0.0
# area_mato                                   0.1
# area_agricola                               0.0
# area_pov_mato                               0.1
# area_total                                  0.1
# reacendimento                                 0
# queimada                                      0
# falso_alarme                                  0
# fogacho                                       1
# incendio                                      0
# agricola                                      0
# perimetro                                   NaN
# aps                                         NaN
# causa                                       NaN
# tipo_causa                                  NaN
# LAT                                   41.202847
# LON                                   -8.204764
# Name: 53, dtype: object
# 2010-07-31_41.2028475_-8.2047635.csv 2010-07-31_41.2028475_-8.2047635_radiation.csv
# True True
# 275.0
# 31.4
# 2010-07-31T15:00
# ano                                        2010
# codigo_sgif                           DM2102850
# tipo                                  Florestal
# distrito                                  Porto
# concelho                     Marco de Canaveses
# freguesia                    Vila Boa de Quires
# local                                 Vilarelho
# ine                                      130731
# x                                      193262.0
# y                                      469964.0
# data_alerta                          2010-07-31
# hora_alerta                            03:35:00
# data_extincao                        2010-07-31
# hora_extincao                          07:28:00
# data_primeira_intervencao            2010-07-31
# hora_primeira_intervencao              03:50:00
# fonte_alerta                          Populares
# nut                                  PT11050931
# area_povoamento                             0.0
# area_mato                                  0.03
# area_agricola                               0.0
# area_pov_mato                              0.03
# area_total                                 0.03
# reacendimento                                 0
# queimada                                      0
# falso_alarme                                  0
# fogacho                                       1
# incendio                                      0
# agricola                                      0
# perimetro                                   NaN
# aps                                         NaN
# causa                                       NaN
# tipo_causa                                  NaN
# LAT                                   41.202847
# LON                                   -8.204764
# Name: 54, dtype: object
# 2010-07-31_41.2028475_-8.2047635.csv 2010-07-31_41.2028475_-8.2047635_radiation.csv
# True True
# 275.0
# 22.6
# 2010-07-31T03:00
